# %%
# ☯ Coding Dojo ☯

# %% [markdown]
# <img style="float:left" src="imgs/vamos_coletar.png">
# ## Regras
#
# Ponto de participação, poderá perdido se:
#
#     - Aluno atrasado (ver política de atraso na especificação)
#     - Recusar participação como piloto/copiloto
#         - Ou não querer sair do computador, quando solicitado :-)
#     - Demorar para sair quando solicitado
#     - Parar de participar por:
#         - Uso de outro computador
#         - Uso de celular
#         - Usar a internet
#         - Conversa

# %% [markdown]
# Antes de entregar, certifique-se que tenha executado todos os comandos/códigos deste Jupyter. É obrigatório que todas as saídas tenham sido apresentadas. Perda de 3 pontos caso não tenham feito isso.

# %% [markdown]
# # Dependencias

# %% [markdown]
# Se necessário, instale o python3 e o pip3 abaixo usando `sudo apt-get install python3 python3-pip`.  Execute abaixo para instalar o [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/). Qualquer linha de comando/código como a de baixo, você pode executá-la a selecionando e pressionando `ctrl+enter` ❣️.

# %%
# !pip3 install bs4
# Out:
# Requirement already satisfied: bs4 in /home/natha/.local/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/natha/.local/lib/python3.8/site-packages (from bs4) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /home/natha/.local/lib/python3.8/site-packages (from beautifulsoup4->bs4) (2.0.1)

# %% [markdown]
# Caso de comando não encontrado `pip3` use `pip`.

# %% [markdown]
# # Coletor

# %% [markdown]
# <img src="imgs/arquitetura_coletor.png">

# %% [markdown]
# Você deverá completar a implementação das três classes abaixo para fazer o coletor: `Domain`, `Scheduler` e `PageFetcher`. Conforme figura acima, o `Scheduler` é responsável por armazenar as filas de URLs a serem requisitadas; o PageFetcher serão *threads* responsáveis por fazer as requisições das URLs obtidas por meio do escalonador (instancia da classe `Scheduler`). A classe `Domain` armazena informações importantes sobre o servidor a serem usadas no momento do escalonamento das URLs.

# %% [markdown]
# ## Classe `Domain`

# %% [markdown]
# <figure style="text-align:center">
#     <img src="imgs/estrutura_coletor.png">
#     <caption>Fonte: Baeza-Yates e Ribeiro-Neto, 2011 </caption>
# </figure>

# %% [markdown]
# Antes de começar a fazer o escalonador (classe `Scheduler`) devemos implementar a classe que representa os domínios. Conforme visto na figura acima, o escalonador possuirá diversas filas, uma para cada servidor.  Em nosso caso, o servidor será um domínio - que você irá implementar na classe `Domain` do arquivo `domain.py`.
#
# O escalonador percorrerá cada servidor e obterá o primeiro da fila do primeiro servidor acessível. O servidor é acessível obdecendo o limite de tempo entre requisições (em segundos, usando o atributo `int_time_limit_between_requests`).
#
# Nesta atividade você irá implementar a classe `Domain`, que já possui os seguintes atributos:
#
# - *int_time_limit_between_requests*: Limite entre requisições (int)
# - *nam_domain*: Nome do domínio (String)
# - *time_last_access*: [Objeto Datetime](https://docs.python.org/3/library/datetime.html#datetime-objects) informando da data/hora do último acesso
#
# O prefixo da variável sempre irá denotar o tipo da mesma.

# %% [markdown]
# **Atividade 1 - classe `Domain`**: Complete a classe `Domain` implementando os métodos/atributos calculados descritos a seguir. Logo após, execute o ❣️ teste unitário ❣️ para verificar se os métodos/atributos calculados foram implementados conforme esperado.
#
# - **accessed_now**: Método que modifica o último acesso com a data/hora atual usando um [objeto datetime](https://docs.python.org/3/library/datetime.html#datetime-objects)
# - **time_since_last_access**: Atributo calculado que retorna um [objeto TimeDelta](https://docs.python.org/3/library/datetime.html#timedelta-objects) com a diferença da data atual e a data do último acesso. Veja os exemplos de uso do TimeDelta na sua documentação
# - **is_accessible**: Método que verdadeiro se o domínio estiver acessível

# %% [markdown]
# Os métodos `count_fetched_page` e `has_finished_crawl` já estão implementados. Execute o teste unitário a seguir. Veja que o comando abaixo executa o teste unitário presente no arquivo `crawler/scheduler_test.py`. Analise-o para entender como implementamos testes unitários.

# %%
# !python3 -m crawler.scheduler_test DomainTest.test_domain
# Out:
# Verificando acesso a um dominio já requisitado (após espera)
# aguardando 10 segundos...
# .
# ----------------------------------------------------------------------
# Ran 1 test in 10.008s
#
# OK

# %% [markdown]
# **Atividade 2 - métodos `__hash__` e `__eq__` da classe `Domain`**: A fila será implementada por um dicionario ordenado ([OrderedDict](https://docs.python.org/2/library/collections.html#collections.OrderedDict)) em que a chave será um objeto da classe domínio e o valor serão uma lista de URLs. Para que seja possível a busca do domínio, você deverá implementar os métodos `__hash__` e `__eq__` de forma similar ao seguinte exemplo:

# %%
from collections import OrderedDict
class Xuxu():
    def __str__(self):
        return "xuxuuu"
    
    def __hash__(self):
        return hash("xuxu")
    def __eq__(self, x):
        return x == "xuxu"
d = OrderedDict()
d[Xuxu()] = 'A'
print("xuxu" in d)
# Out:
# True

# %% [markdown]
# Em nosso caso, deve ser permitido fazer a busca no dicionario pelo nome do domínio ou pelo objeto, ou seja, após a implementação desta atividade, o seguinte código irá funcionar corretamente:

# %%
from crawler.domain import Domain
from collections import OrderedDict

obj_domain = Domain("oi.com",10)
dic_x = OrderedDict()
dic_x[obj_domain] = "lala"
dic_x["oi.com"] = "oi"

#abaixo, em ambos os casos, será encontrado/impresso a string "oi"
print(dic_x["oi.com"])
print(dic_x[obj_domain])
# Out:
# oi
# oi

# %% [markdown]
# Lembre-se que, em nosso caso, o parametro do método `__eq__` pode ser um objeto da classe `Domain` ou uma string representando o nome do domínio. Caso faça alguma modificação no código, você deverá reiniciar o kernel para que o efeito seja visto no código acima (para reiniciar, clique em Kernel->Restart). Isso ocorre que, uma vez dado import em um módulo, esse modulo não é alterado no Jupyter caso você faça uma modificação no código.

# %% [markdown]
# ## Classe `Scheduler`

# %% [markdown]
# Agora você irá implementar o escalonador. Essa classe será responsável por gerenciar as URLs.
# Para isso, será implementado as filas por servidores conforme apresentado na figura da seção anterior.
# Para isso, utilizaremos um OrderedDict em que as chaves são os servidores (objeto da classe `Domain`) e o valor será uma lista de tuplas com as URLs e sua profundidade. Com o objetivo de armazenar as URLs de forma estruturada, as mesmas **não serão** string, ao invés disso, serão objetos da classe `ParseResult` - essa classe é retornada do método [urlparse](https://docs.python.org/3/library/urllib.parse.html). Veja um exemplo abaixo.

# %%
from crawler.domain import Domain
from crawler.scheduler import Scheduler
from urllib.parse import urlparse

dict_filas_por_servidor = {Domain("www.globo.com",10):[(urlparse("http://www.globo.com/esporte"),1),
                                                (urlparse("http://www.globo.com/noticia_um"),2),
                                                (urlparse("http://www.globo.com/noticia_dois"),3),
                                                (urlparse("http://www.globo.com/noticia_tres"),3),
                                                ],
                            Domain("www.cnpq.br",10):[(urlparse("http://www.cnpq.br/pesquisadores"),1),
                                               (urlparse("http://www.cnpq.br/bolsas"),1)]
                          }

# %% [markdown]
# Assim, a classe `Scheduler`, no arquivo `scheduler.py` possui os seguintes atributos:
#
# - `str_usr_agent`: Nome do `User agent`. Usualmente, é o nome do navegador, em nosso caso,  será o nome do coletor (usualmente, terminado em `bot`)
# - `int_page_limit`: Número de páginas a serem coletadas
# - `int_depth_limit`: Profundidade máxima a ser coletada
# - `int_page_count`: Quantidade de página já coletada
# - `dic_url_per_domain`: Fila de URLs por domínio (explicado anteriormente)
# - `set_discovered_urls`: Conjunto de URLs descobertas, ou seja, que foi extraída em algum HTML e já adicionadas na fila - mesmo se já ela foi retirada da fila. A URL armazenada deve ser uma string.
# - `dic_robots_per_domain`: Dicionário armazenando, para cada domínio, o objeto representando as regras obtidas no `robots.txt`

# %% [markdown]
# **Atividad 3 - Método `can_add_page`**: Esse método irá retornar verdadeiro caso seja possível adicionar a página `obj_url` (objeto da classe ParseResult) que foi coletada na profundidade `int_depth`. Para que seja possível adicionar na lista, esta pagina não deve ter sido descoberta e nem com a profundidade maior que o limite. Este método será testado por teste unitário apenas após a implementação da adição e obtenção das URLs.

# %% [markdown]
# **Atividade 4 método `add_new_page` - Adicionar nova página**:  Este método retorna falso caso não seja possível adicionar a página (por meio do método `can_add_page`) e verdadeiro, caso contrário. Caso seja possível, deve-se adicionar a url `obj_url` na fila `dic_url_per_domain`. Lembre-se da estrutura do dicionário `dic_url_per_domain`. Não esqueça de armazenar que esta URL já foi descoberta. Este método será testado por teste unitário apenas após a implementação da obtenção das URLs. Lembre-se de como trabalhar com [dicionários](https://daniel-hasan.github.io/cefet-web-grad/classes/python2/#mais-colecoes)

# %% [markdown]
# **Atividade 5 método `get_next_url` - obtém a próxima URL da fila**: Este método retona uma tupla `url,profundade` da próxima URL a ser coletada por meio da fila `dic_url_per_domain` retirando este item da fila. Lembre-se que:
#
# - Ele deverá retornar a primeira URL do primeiro servidor que estiver acessível.
# - Você deve indicar que o servidor foi acessado
# - Caso a fila deste servidor esteja vazia, elimine-o do dicionário
# - Caso não encontre a URL, [coloque a Thread para esperar](https://docs.python.org/2/library/time.html#time.sleep) e, logo após, procure novamente
#
# Logo após, você já pode executar o teste unitário para verificar se a obtenção e adição de URLs está correta. Caso haja algum problema, existem já alguns prints comentados no código, descomente-os para verificar se o fluxo está ocorrendo da forma correta. Você deverá entregar sem a exibição desses prints (caso contrário, perderá pontos).

# %%
# !python3 -m crawler.scheduler_test SchedulerTest.test_add_remove_pages
# Out:
# Verificação da ordem das URLs...
# Resgatando a segunda página do mesmo dominio...
# Tempo esperado: 20 segundos
# .
# ----------------------------------------------------------------------
# Ran 1 test in 20.021s
#
# OK

# %% [markdown]
# **Atividade 6 método `can_fetch_page`**: Este método deve retornar verdadeiro caso a url (Objeto `ParseResult`), passada como parâmetro, pode ser coletada de acordo com o `Robots.txt` do domínio. Para isso, você deve usar o [`RobotFileParser`](https://docs.python.org/3/library/urllib.robotparser.html). Por razões de performance, você só poderá requisitar o robots.txt uma única vez por domínio. Assim, use o `dic_robots_per_domain` apropriadamente. Execute o teste unitário abaixo para verificar seu funcionamento.

# %%
# !python3 -m crawler.scheduler_test SchedulerTest.test_can_fetch_page
# Out:
# E
# ======================================================================
# ERROR: test_can_fetch_page (__main__.SchedulerTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/natha/CEFET/crawlerRI/tp-crawler/crawler/scheduler_test.py", line 88, in test_can_fetch_page
#     obj_robot_not_allowed = self.scheduler.dic_robots_per_domain[obj_url_not_allowed.netloc]
# KeyError: 'www.globo.com'
#
# ----------------------------------------------------------------------
# Ran 1 test in 1.995s
#
# FAILED (errors=1)

# %% [markdown]
# **Atividade 7 - Inicialização das sementes no contrutor**: No contrutor da classe `Scheduler` você deve adicionar as páginas sementes na fila. Tais sementes são passadas pelo parametro `arr_urls_seeds` do contrutor.

# %%
# !python3 -m crawler.scheduler_test SchedulerTest.test_init
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK

# %% [markdown]
# Logo após, utize a anotação @synchronized aonde julgar necessário para transformar em ThreadSafe.

# %% [markdown]
# ## PageFetcher

# %% [markdown]
# **Atividade 8 - Efetuar a requisição - método `request_url`:** Neste método você irá fazer a requisição usando a api [requests](https://requests.readthedocs.io/en/master/). Além disso, deve-se informar no cabeçalho (em `User-Agent`) o nome do coletor. O método deverá retornar o conteúdo (em binário) apenas se o conteúdo for HTML (ver no cabeçalho da resposta o tipo do conteúdo). Caso não seja, ele deverá retornar nulo.

# %%
# !python3 -m crawler.page_fetcher_test PageFetcherTest.test_request_url
# Out:
# URL do request: http://www.google.com.br
# URL do request: https://code.jquery.com/jquery-3.4.1.js
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.571s
#
# OK

# %% [markdown]
# **Atividade 9 extração das URLs por meio do método `discover_links`**: A partir do conteúdo (texto em binário) `bin_str_content` deve-se extrair seus os links. O conteúdo esta em binário, pois, o BeautifulSoup, internamente, verifica o encoding por meio da [tag meta](https://www.w3schools.com/tags/att_meta_charset.asp) e converte para UTF8. A URL da página coletada é um objeto ParseResult `obj_url` que está na profundidade `int_depth`.
#
# Para cada URL extraída, você deverá retornar uma tupla com a URL (objeto ParseResult) e a sua profundidade. Utilize o comando `yield` para retornar essas tuplas. A profundidade é calculada de por meio de  `obj_url` e `int_depth`, conforme comentado em sala de aula.
#
# Para a extração dos links, use o [CSS Selector do BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#css-selectors). Seletor CSS é uma expressão que define quais elementos HTML serão estilizados pelo CSS. No *Beatifulsoup* eles são usados para selecionar quais tags serão extraídas. Veja o exemplo de uso e brinque abaixo. Caso precise, veja aqui um pouco de seletores CSS: [slides de Web](https://fegemo.github.io/cefet-front-end/classes/css2/#outros-seletores), [documentação MDN](https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Selectors).

# %%
from bs4 import BeautifulSoup

# %%
# !python3 -m crawler.page_fetcher_test PageFetcherTest.test_discover_links
# Out:
# Simulação da extração de links da página http://www.pudim.com.br na profundidade nível 2...
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# **Atividade 10 - método que solicita uma nova URL**: Por meio do método `crawl_new_url` você deverá utilizar os métodos previamente implementados para:
#
# - Solicitar ao escalonador uma nova URL
# - Fazer a requisição e obter o resultado (em binário)
# - Caso a URL seja um HTML válido, imprima esta URL e extraia os seus links

# %% [markdown]
# **Atividade 12 - método run**: Este método deve coletar páginas enquanto a coleta não foi finalizada

# %% [markdown]
# **Atividade 11 - um pequeno teste para finalizar: ** Use as sementes do seu grupo e crie abaixo um escalonador e 5 PageFetchers para extrair 30 páginas. Imprima também o tempo gasto total.

# %%
from crawler.scheduler import Scheduler
from crawler.page_fetcher import PageFetcher
from datetime import datetime

arr_urls_seeds = ["http://www.crea-mg.org.br","https://www.cefetmg.br","https://youtube.com"]
scheduler = Scheduler(str_usr_agent="CrawlerBot(nathaclmpaulino.github.io/crawlerRI/infoCrawlerBot)", int_page_limit=30, int_depth_limit=3, arr_urls_seeds=arr_urls_seeds)

pf1 = PageFetcher(scheduler)
pf2 = PageFetcher(scheduler)
pf3 = PageFetcher(scheduler)
pf4 = PageFetcher(scheduler)
pf5 = PageFetcher(scheduler)

start = datetime.now()

pf1.run()
pf2.run()
pf3.run()
pf4.run()
pf5.run()

end = datetime.now()
diff = end - start

print('Tempo de coleta: ' + str(diff.total_seconds()))
# Out:
# http://www.crea-mg.org.br
# https://www.cefetmg.br
# https://youtube.com
# https://www.copeve.cefetmg.br/processos/20202_SUP
# https://youtu.be/OJKxWMLX3I0
# http://www.eng-automacao.araxa.cefetmg.br/
# http://www.eng-minas.araxa.cefetmg.br/
# http://www.administracao.bh.cefetmg.br/
# http://www.eng-computacao.bh.cefetmg.br/
# http://www.eng-eletrica.bh.cefetmg.br
# http://www.eng-mecanica.bh.cefetmg.br/
# http://www.eng-civil.bh.cefetmg.br/
# http://www.eng-ambiental.bh.cefetmg.br/
# http://www.eng-materiais.bh.cefetmg.br/
# http://www.eng-transportes.bh.cefetmg.br/
# http://www.letras.bh.cefetmg.br/
# http://www.quimicatecnologica.bh.cefetmg.br/
# http://www.eng-civil.curvelo.cefetmg.br/
# http://www.designdemoda.divinopolis.cefetmg.br/
# http://www.eng-computacao.divinopolis.cefetmg.br/
# http://www.eng-mecatronica.divinopolis.cefetmg.br/
# http://www.eng-computacao.leopoldina.cefetmg.br/
# http://www.eng-controleautomacao.leopoldina.cefetmg.br/
# http://www.eng-eletrica.nepomuceno.cefetmg.br/
# http://www.eng-computacao.timoteo.cefetmg.br/
# http://www.eng-metalurgica.timoteo.cefetmg.br/
# http://www.eng-civil.varginha.cefetmg.br/
# https://www.youtube.com/about/
# https://developers.google.com/youtube
# https://www.google.com.br/intl/pt-BR/policies/privacy/
# https://policies.google.com/privacy?hl=pt-BR
# https://www.cefetmg.br/
# https://youtube.com//t/contact_us
# https://www.copeve.cefetmg.br/
# https://youtu.be//t/contact_us
# https://www.youtube.com/about/press/
# http://www.cefetmg.br/home-page/
# https://youtube.com//t/terms
# http://www.dept.cefetmg.br/
# http://www.dirgrad.cefetmg.br/
# http://www.dppg.cefetmg.br/
# http://www.dpg.cefetmg.br/
# http://www.dedc.cefetmg.br/
# http://www.sgi.cefetmg.br/
# http://www.secom.cefetmg.br/
# http://www.segep.cefetmg.br/
# http://www.spe.cefetmg.br/
# http://www.srca.cefetmg.br/
# http://www.sri.cefetmg.br/
# http://www.conselhodiretor.cefetmg.br/
# http://www.cepe.cefetmg.br/
# http://www.vestibular.cefetmg.br
# http://www.cpa.cefetmg.br/
# http://www.cppi.cefetmg.br/
# http://www.araxa.cefetmg.br/
# http://www.campus1.cefetmg.br/
# http://www.campus2.cefetmg.br/
# http://www.campus6.cefetmg.br/
# http://www.contagem.cefetmg.br/
# http://www.curvelo.cefetmg.br/
# http://www.divinopolis.cefetmg.br/
# http://www.leopoldina.cefetmg.br/
# http://www.nepomuceno.cefetmg.br/
# http://www.timoteo.cefetmg.br/
# http://www.varginha.cefetmg.br/
# http://www.cgdct.cefetmg.br/
# http://www.cgpgl.cefetmg.br/
# http://www.cep.cefetmg.br/
# http://www.somos.cefetmg.br/
# https://periodicos.cefetmg.br/index.php/revista-et
# http://www.bu.cefetmg.br/
# http://www.estagio.cefetmg.br/
# http://www.egressos.cefetmg.br/
# https://iu.cefetmg.br/
# https://ava.cefetmg.br/
# https://youtu.be//t/terms
# https://sig.cefetmg.br/admin/public/loginunificado/index.jsf
# http://www.prefeitura.cefetmg.br/
# https://cs.sgi.cefetmg.br/
# http://www.mapa.cefetmg.br/
# http://www.transparencia.gov.br/convenios/consulta?periodoLiberacaoRecursosDe=01%2F01%2F2018&periodoLiberacaoRecursosAte=31%2F12%2F2018&orgaos=OR26257&ordenarPor=concedente&direcao=desc
# http://www.sccont.cefetmg.br/
# http://www.slog.cefetmg.br/divisao-de-compras-dicom/licitacoes/
# http://www.portaltransparencia.gov.br/?minifiedPath=%2Fminified&projectVersion=1.11.0
# http://www.cgu.gov.br/acessoainformacaogov/materiais-interesse/CartilhaAcessoaInformacao.pdf
# http://www.audit.cefetmg.br/
# https://email.cefetmg.br/
# https://seer.dppg.cefetmg.br/
# http://www.sinapse.cefetmg.br/jsp/gru/pagina/manterguiagru/emitirguiagru.jsf
# https://grupos.cefetmg.br/wws
# https://www.cefetmg.br/instituicao/
# https://youtube.com//new
# https://youtu.be//new
# https://www.youtube.com/about/copyright/
# http://www.dept.cefetmg.br/apresentacao-2/
# http://www.dirgrad.cefetmg.br/conselho-de-graduacao/apresentacao/
# http://www.dppg.cefetmg.br/cppg/apresentacao/
# http://www.dedc.cefetmg.br/o-conselho/
# http://www.sgi.cefetmg.br/rede-sem-fio/
# http://www.secom.cefetmg.br/tunel/
# http://www.segep.cefetmg.br/professor-substituto/selecao-prof-substituto/
# http://www.spe.cefetmg.br/orientacoes-de-utilizacao/
# https://www.vestibular.cefetmg.br/
# http://www.campus1.cefetmg.br/intercampi/
# https://iu.cefetmg.br/login/?next=/
# https://sig.cefetmg.br/sigaa
# http://www.prefeitura.cefetmg.br
# https://cs.sgi.cefetmg.br
# http://www.transparencia.gov.br/despesas/orgao?&orgaos=OR26257&ordenarPor=orgaoSuperior&direcao=asc
# http://www.cgu.gov.br/acessoainformacaogov/acesso-informacao-brasil/legislacao-integra-texto-completo.asp
# https://www2.cefetmg.br/textoGeral/Boletim/boletim.html
# https://twitter.com/cefet_mg
# https://www.facebook.com/cefetmg
# https://www.instagram.com/cefetmg/
# https://webmail.cefetmg.br
# https://www.linkedin.com/edu/school?id=10506&trk=prof-following-school-logo
# http://l.facebook.com/l.php?u=http%3A%2F%2Fshare.here.com%2Fr%2Fmylocation%2Fe-%3D%3D%3Flink%3Daddresses%26fb_locale%3Dpt_BR%26ref%3Dfacebook&h=AT10dk_pYrkhiWb1NLeTS9C0zXn62spVAX5_j7_jxnd5ENOHgyHu9GPUB_y03DcBTqW1Jyu0nLVGOPGL0UVyu4-NUUuVc-2TOPkM-hwbon09pZSm_wj5V5X9cFC1jHDP65oYbc38_F0JM-5bQJYOt2DWW5OCNLTW
# https://www.cefetmg.br/instituicao/historia/
# https://www.youtube.com/creators/
# http://www.dirgrad.cefetmg.br/wp-content/uploads/sites/81/2019/01/2019_1_Guia_Graduacao_A5_CEFETMG_WEB.pdf
# http://www.dppg.cefetmg.br/coordenacao-de-fomento/
# http://www.sgi.cefetmg.br/pda/
# http://www.segep.cefetmg.br/servicos/professor-substituto/selecao-prof-substituto/
# https://sig.cefetmg.br/sipac/
# http://www.prefeitura.cefetmg.br/lista-telefonica-do-cefet-mg/
# https://www.facebook.com/
# https://es-la.facebook.com/
# https://fr-fr.facebook.com/
# https://it-it.facebook.com/
# https://ar-ar.facebook.com/
# https://de-de.facebook.com/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.cefetmg.br%2F&h=AT2OdSxPaaUp7BLqO_xUWP63f1NYCg3LIQ9WSo4n7b2UV3SZ3WyR9PnLnCw-4HrQGvCLxP-BYHJD-lD6mcHmZTmzEOoPj86NQG2xsCmvbVrX5m8ajr8ay_FFs1tANSceJ-LbMAQH8x8IOG_7CV4TL5tLEsuKKseb
# https://hi-in.facebook.com/
# https://zh-cn.facebook.com/
# https://ja-jp.facebook.com/
# https://messenger.com/
# https://pay.facebook.com/
# https://www.oculus.com/
# https://portal.facebook.com/
# https://developers.facebook.com/?ref=pf
# https://pt-br.facebook.com/
# https://es-la.messenger.com/
# https://fr-fr.messenger.com/
# https://it-it.messenger.com/
# https://ar-ar.messenger.com/
# https://de-de.messenger.com/
# https://hi-in.messenger.com/
# https://zh-cn.messenger.com/
# https://ja-jp.messenger.com/
# https://pt-br.messenger.com/
# https://www.cefetmg.br/instituicao/quem-e-quem/
# https://www.youtube.com/ads/
# http://www.dirgrad.cefetmg.br/dirgrad/editais/
# http://www.dppg.cefetmg.br/programas-stricto-sensu/
# http://www.sgi.cefetmg.br
# https://sig.cefetmg.br/sigrh
# https://www.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://es-la.facebook.com/recover/initiate/?ars=facebook_login
# https://fr-fr.facebook.com/recover/initiate/?ars=facebook_login
# https://it-it.facebook.com/recover/initiate/?ars=facebook_login
# Tempo de coleta: 416.310158

# %%
from crawler.scheduler import Scheduler
from crawler.page_fetcher import PageFetcher
from datetime import datetime
import pandas as pd

list_start = []
list_end   = []
list_diff  = []

def run_fetchers(int_thread_number, scheduler):
    lista = []
    for i in range(int_thread_number):
        lista.append(PageFetcher(scheduler))
    
    start = datetime.now()
    for i in range(int_thread_number):
        lista[i].run()
    end = datetime.now()
    
    exectime = end - start
    
    list_start.append(start)
    list_end.append(end)
    list_diff.append(exectime.total_seconds())

    

arr_urls_seeds = ["http://www.crea-mg.org.br","https://www.cefetmg.br","https://kubernetes.io/"]
scheduler1 = Scheduler(str_usr_agent="CrawlerBot(nathaclmpaulino.github.io/crawlerRI/infoCrawlerBot)", int_page_limit=500, int_depth_limit=6, arr_urls_seeds=arr_urls_seeds)
scheduler2 = Scheduler(str_usr_agent="CrawlerBot(nathaclmpaulino.github.io/crawlerRI/infoCrawlerBot)", int_page_limit=500, int_depth_limit=6, arr_urls_seeds=arr_urls_seeds)
scheduler3 = Scheduler(str_usr_agent="CrawlerBot(nathaclmpaulino.github.io/crawlerRI/infoCrawlerBot)", int_page_limit=500, int_depth_limit=6, arr_urls_seeds=arr_urls_seeds)
scheduler4 = Scheduler(str_usr_agent="CrawlerBot(nathaclmpaulino.github.io/crawlerRI/infoCrawlerBot)", int_page_limit=500, int_depth_limit=6, arr_urls_seeds=arr_urls_seeds)
scheduler5 = Scheduler(str_usr_agent="CrawlerBot(nathaclmpaulino.github.io/crawlerRI/infoCrawlerBot)", int_page_limit=500, int_depth_limit=6, arr_urls_seeds=arr_urls_seeds)
scheduler6 = Scheduler(str_usr_agent="CrawlerBot(nathaclmpaulino.github.io/crawlerRI/infoCrawlerBot)", int_page_limit=500, int_depth_limit=6, arr_urls_seeds=arr_urls_seeds)

run_fetchers(10, scheduler1)
print('Done - 10')
run_fetchers(30, scheduler2)
print('Done - 30')
run_fetchers(50, scheduler3)
print('Done - 50')
run_fetchers(70, scheduler4)
print('Done - 70')
run_fetchers(90, scheduler5)
print('Done - 90')
run_fetchers(100, scheduler6)
print('Done - 100')
# Out:
# https://www.cefetmg.br
# https://youtu.be/OJKxWMLX3I0
# https://www.google.com.br/intl/pt-BR/policies/privacy/
# https://www.cefetmg.br/
# https://youtu.be//t/contact_us
# http://www.cefetmg.br/home-page/
# https://youtu.be//t/terms
# https://email.cefetmg.br/
# https://www.cefetmg.br/instituicao/
# https://www.cefetmg.br/instituicao/historia/
# https://youtu.be//new
# https://www.facebook.com/cefetmg
# https://www.instagram.com/cefetmg/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fshare.here.com%2Fr%2Fmylocation%2Fe-%3D%3D%3Flink%3Daddresses%26fb_locale%3Dpt_BR%26ref%3Dfacebook&h=AT3cKu3NJhT7qUMRHuSR6c71XTz1dK1uHFBsahMe65Bcw8Ri_95ZmlnTG6huQ0LknQdBMBbVx2KbCFVwxet7WLu8OHCcRh1JaW1CbDjUOZH4RsNE8J-gVFYBklobz7vjIZKY69ShleIL2GqNvyVfXQ-9c_QMCm0E
# https://www.cefetmg.br/instituicao/quem-e-quem/
# https://youtu.be//t/contact_us/
# https://www.facebook.com/
# https://es-la.facebook.com/
# https://fr-fr.facebook.com/
# https://it-it.facebook.com/
# https://ar-ar.facebook.com/
# https://de-de.facebook.com/
# https://hi-in.facebook.com/
# https://zh-cn.facebook.com/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.cefetmg.br%2F&h=A
# https://zh-cn.facebook.com//policies/cookies/
# https://ja-jp.facebook.com//policies/cookies/
# https://pt-br.facebook.com//policies/cookies/
# https://www.cefetmg.br/editais-e-chamadas-publicas/
# https://www.facebook.com/gremiocefetbh/?ref=py_c
# https://es-la.facebook.com//policies
# https://www.intern.facebook.com/
# http://www.fulbright.org.br
# https://ar-ar.facebook.com/help/568137493302217
# https://fulbright.org.br/comissao/
# https://www.instagram.com/fulbrightbrasil/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fshare.here.com%2Fr%2Fmylocation%2Fe-%3D%3D%3Flink%3Daddresses%26fb_locale%3Dpt_BR%26ref%3Dfacebook&h=AT1L9p6pGXaTUwzGi4tGRaPan8s2MozRAl81fN3VL2SZkQUco5KwfjCcnWt3sWYRFEA0NOORrkrKGYhuyPnP54WOAw3b8e--cSC9Do5XWW3rjBluwi_E97ku2FXa4gIsBPhsOxj8wXtkxI5JuAPvhzpYwE6G4xau
# https://fr-fr.facebook.com//policies
# https://de-de.facebook.com/help/568137493302217
# https://hi-in.facebook.com/help/568137493302217
# https://it-it.facebook.com//policies
# https://zh-cn.facebook.com/help/568137493302217
# https://ja-jp.facebook.com/help/568137493302217
# https://pt-br.facebook.com/help/568137493302217
# https://www.cefetmg.br/aluno/
# https://www.facebook.com/fcm.idiomas/?ref=py_c
# https://es-la.facebook.com//help/
# https://www.intern.facebook.com//r.php
# http://www.fulbright.org.br/
# https://ar-ar.facebook.com//policies
# https://fulbright.org.br/bolsas-para-brasileiros/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.cefetmg.br%2F&h=AT0lNVFZRx7QxSDpTL89BeLtdm9PgZsrGqqA0JRTcMwdJQEhjFYCFP_BG1a7ZUUrmiX5QxPfR5CIW0_GmiEGDW07tgJ9PbS7h5dVkvRGsf4bTjZpbD-qi-cHdQ0v41_j0eDZGvVbV0bECGziQ4CqNmVD4IF-dcU2
# https://fr-fr.facebook.com//help/
# https://de-de.facebook.com//policies
# https://hi-in.facebook.com//policies
# https://it-it.facebook.com//help/
# https://zh-cn.facebook.com//policies
# https://ja-jp.facebook.com//policies
# https://pt-br.facebook.com//policies
# https://www.cefetmg.br/aluno/servicos/
# https://www.facebook.com/feiracefettec/?ref=py_c
# https://es-la.facebook.com//settings
# https://www.intern.facebook.com//login/
# https://ar-ar.facebook.com//help/
# https://fulbright.org.br/grants-for-us-citizens/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.cefetmg.br%2F&h=AT0B-Fr_InKmELrjvjq-Ude59EHw59CzQdNxtd2e5rzKJZXHEdijAiD2WfeLoVrPKkW4Yuy1IvrTaHepsYQGqq1h9tU9JsJ4_LwEULeKnxBwm4WxMoc5K47QrhnknqimmVdC4ewJMqWwvjzONKv0C5MbMq9qUGfVgqI
# https://fr-fr.facebook.com//settings
# https://de-de.facebook.com//help/
# https://hi-in.facebook.com//help/
# https://it-it.facebook.com//settings
# https://zh-cn.facebook.com//help/
# https://ja-jp.facebook.com//help/
# https://pt-br.facebook.com//help/
# https://www.cefetmg.br/calendario-academico/
# https://www.facebook.com/inatel/?ref=py_c
# https://www.intern.facebook.com//lite/
# https://ar-ar.facebook.com//settings
# https://fulbright.org.br/alumni/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fbit.ly%2F3dqbHLz&h=A

# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT3F2FmSEgfWvbaji5QYs0eCKWZvqd-D0dnHDWuVVT-4O4HBelKdvv08Ujhm8Zf0QUXEgX33rHEf5UypiD4XcPSK3Wh4HYuznKJK-zTPJ2AT9qPzret4Bysvw-9obLkRsfS_13dg3jqmuMLDn9qwQnzl2WKHMklq
# https://fulbright.org.br/
# https://fr-fr.facebook.com/login/
# https://www.instagram.com/mineducacao
# https://it-it.facebook.com/login/
# https://de-de.facebook.com/cefetmg/reviews/
# https://hi-in.facebook.com/cefetmg/reviews/
# Done - 10
# https://www.cefetmg.br
# https://youtu.be/OJKxWMLX3I0
# https://www.google.com.br/intl/pt-BR/policies/privacy/
# https://www.cefetmg.br/
# https://youtu.be//t/contact_us
# http://www.cefetmg.br/home-page/
# https://youtu.be//t/terms
# https://email.cefetmg.br/
# https://www.cefetmg.br/instituicao/
# https://youtu.be//new
# https://www.facebook.com/cefetmg
# https://www.instagram.com/cefetmg/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fshare.here.com%2Fr%2Fmylocation%2Fe-%3D%3D%3Flink%3Daddresses%26fb_locale%3Dpt_BR%26ref%3Dfacebook&h=AT08AUs1-ssu_2slh564VwbHfxXIGr852TPSjPyAYqGFbkqwIJo6J7pbqK5vP92bRzNvMq4aGPhVWrPlOsqeoPNft9agOjLCM0hzTjdyNXz6LQqPeDgZaaAWnEetX6jnzh-xQmIdQ8IW9IjuQmWHfLtSx5zAJlrj
# https://www.cefetmg.br/instituicao/historia/
# https://www.facebook.com/
# https://es-la.facebook.com/
# https://fr-fr.facebook.com/
# https://it-it.facebook.com/
# https://ar-ar.facebook.com/
# https://de-de.facebook.com/
# https://hi-in.facebook.com/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.cefetmg.br%2F&h=AT3xjKLRORo26dNjcXH4upPbt9k9ys_-2VLIzNB2bvA-k6TQJnBYtkhMNYh_W3zCPrK-a1AsP8vzq661mMDeJ02GQrPK3V9IjO9YG5WQ4xXKghMwYRrprveEIlLKJ6RZIE4IAApdtBesMiZk1l_1zrWJh_gX1Y70
# https://zh-cn.facebook.com/
# https://ja-jp.facebook.com/
# https://pt-br.facebook.com/
# https://www.cefetmg.br/instituicao/quem-e-quem/
# https://www.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://es-la.facebook.com/recover/initiate/?ars=facebook_login
# https://fr-fr.facebook.com/recover/initiate/?ars=facebook_login
# https://it-it.facebook.com/recover/initiate/?ars=facebook_login
# https://ar-ar.facebook.com/recover/initiate/?ars=facebook_login
# https://de-de.facebook.com/recover/initiate/?ars=facebook_login
# https://hi-in.facebook.com/recover/initiate/?ars=facebook_login
# http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.cefetmg.br%2F&h=AT0SA6PdTSM-bAzfs7Dij6dQNHfeqQ5IRWwDQRXSD5jdxUJ9RGAkpKweFZTSo4xk8huJS6NIEiGH9lYps4boUaMKGtAGhR0NUAQwO0jfpcFA-7lUUClQ54R41-M_y3M-U-tAgSSYenN0T7-MtsdSQUsMjEu0lT89rvI
# https://zh-cn.facebook.com/recover/initiate/?ars=facebook_login
# https://ja-jp.facebook.com/recover/initiate/?ars=facebook_login
# https://pt-br.facebook.com/recover/initiate/?ars=facebook_login
# https://www.facebook.com//cefetmg/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fbit.ly%2F3dqbHLz&h=AT2zKn_jstNXlDgeYSWuX0fct_Bb6toj7wiGRewjG1EfUULRHgntIx7BGOkGlUMKxgHXAbTvcabwa8p5bUq7HnJK14LlauyrcxnMmvvCvwq99ZWiAnrDAZcdODPdp_c_TsSic5MrzwsBqXlnvdhDMvF5xKLriQtp5TJ1_QW4I8YyzpNmHnQ
# https://www.cefetmg.br/fotos/
# https://www.facebook.com//cefetmg/about/
# https://es-la.facebook.com//r.php
# https://fr-fr.facebook.com//r.php
# https://it-it.facebook.com//r.php
# https://ar-ar.facebook.com//r.php
# https://de-de.facebook.com//r.php
# https://hi-in.facebook.com//r.php
# https://l.facebook.com/l.php?u=https%3A%2F%2Fbit.ly%2F3dqbHLz&h=AT3qtTYxL4EAxuw3MNwZedKyihMjpakPN3YB6_ktjW1Fa0X6p4XETPiz79qhzgNVHIOIn1SX8Om6pJwxjndo1SJnCx2jgojwnnKYknR9TA4I5ggY5tyvQBbalNf4v50VS60DQn8JeBkb5jhBu4auk5ViQ6GlZvnxF-ygXsJuwf4bZWGjj80
# https://zh-cn.facebook.com//r.php
# https://ja-jp.facebook.com//r.php
# https://pt-br.facebook.com//r.php
# https://www.cefetmg.br/instituicao/plano-de-desenvolvimento-institucional-pdi/
# https://www.facebook.com//cefetmg/reviews/
# https://es-la.facebook.com//login/
# https://fr-fr.facebook.com//login/
# https://it-it.facebook.com//login/
# https://ar-ar.facebook.com//login/
# https://de-de.facebook.com//login/
# https://hi-in.facebook.com//login/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fbit.ly%2F3dqbHLz&h=AT3nuTn2wKtXJlE1_0VM9lyReJiipzqs3YmcT44SgzyAfjyHzhRpByCyrDda5FHL_T15ZKjjxSqqQJtrcxfRLXmOr9dEyk2t7YJXWhgOZLO9ZuI7jfNf6NWBhbstIWEtJMf7UyHcdFpe9vkYAXGgeELMm0BFBbobwccFcZUPpZY1S9KsC-aiYZn5i_z1xieI4mZeoWBI6Q
# https://zh-cn.facebook.com//login/
# https://ja-jp.facebook.com//login/
# https://pt-br.facebook.com//login/
# https://www.cefetmg.br/instituicao/estatuto-do-cefet-mg/
# https://www.facebook.com//cefetmg/photos/
# https://es-la.facebook.com//lite/
# https://fr-fr.facebook.com//lite/
# https://it-it.facebook.com//lite/
# https://ar-ar.facebook.com//lite/
# https://de-de.facebook.com//lite/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT1cweiPuR6pkSiUDM5INCdp_RBOt5QsT1UJb9-mkFlKuZKNAKxLzMRin7M-9EaURHnLqz0YRSf4u57ot425ZVqGhpwLcXAEPSn52nVVDdvLZ9R27XzdARXx6mbL_dAUFxMo2fZeRch2JCx-UgVsmqufuqWGmAxaPvRHZP7vvSEc4w
# https://hi-in.facebook.com//lite/
# https://zh-cn.facebook.com//lite/
# https://ja-jp.facebook.com//lite/
# https://pt-br.facebook.com//lite/
# https://www.cefetmg.br/instituicao/numeros/
# https://www.facebook.com//cefetmg/videos/
# https://es-la.facebook.com/watch/
# https://fr-fr.facebook.com/watch/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT3dc1WYnJZi7-wbelR1x8ZJdYIWTnH6xm6WCpv96nGz5oqX9KlctMkJ213SzBGkmcS2ERGUKesTpvd5tWN12sC79ICMF2EHOE5Qh2AJf-y77kVruN4C7i2AmKKBxDGC4m5tBN6iwqbTxLX7SlXW2I3U4lnZjuzDvlNbYH895YzxMg
# https://it-it.facebook.com/watch/
# https://ar-ar.facebook.com/watch/
# https://de-de.facebook.com/watch/
# https://hi-in.facebook.com/watch/
# https://zh-cn.facebook.com/watch/
# https://ja-jp.facebook.com/watch/
# https://pt-br.facebook.com/watch/
# https://www.cefetmg.br/instituicao/relatorios-de-gestao/
# https://www.facebook.com//cefetmg/posts/
# https://es-la.facebook.com//directory/people/
# https://fr-fr.facebook.com//directory/people/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT3MJvh7MMznOXRpe6Ak2Y_A4OrXeAkmAni1UFNofMhQRgk5Lwq9PB8E3y_sicIWi182eGWvKF3KJ13qBEYmnbslDHvLjG9rMUIyq3hiwxvgB-D2ikqWvQxzU2GrdLlkYmR3dxY_PWE3Ux_i_7JVzas1tSKyCF6b
# https://it-it.facebook.com//directory/people/
# https://ar-ar.facebook.com//directory/people/
# https://de-de.facebook.com//directory/people/
# https://hi-in.facebook.com//directory/people/
# https://zh-cn.facebook.com//directory/people/
# https://ja-jp.facebook.com//directory/people/
# https://pt-br.facebook.com//directory/people/
# https://www.cefetmg.br/instituicao/cefet-mg-em-numeros/
# https://www.facebook.com//cefetmg/community/
# https://es-la.facebook.com//directory/pages/
# https://fr-fr.facebook.com//directory/pages/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT2toKmcu0b8L-Kqe6fqZ29WppOk7r_8SdLZaCNSfg61trmNiEaAt7vavQJPJjbk1xXK2kptQ37RFqTxyfzJWJE5RowUIWKy4u8g5vb587khxSjlrXTtTh9lrcqZULEhhiK4dGFpKKXXot7MRniJc5AjOE0_Vk_s
# https://it-it.facebook.com//directory/pages/
# https://ar-ar.facebook.com//directory/pages/
# https://de-de.facebook.com//directory/pages/
# https://hi-in.facebook.com//directory/pages/
# https://zh-cn.facebook.com//directory/pages/
# https://ja-jp.facebook.com//directory/pages/
# https://pt-br.facebook.com//directory/pages/
# https://www.cefetmg.br/instituicao/dados-estatisticos/
# https://www.facebook.com//cefetmg/events/
# https://es-la.facebook.com//pages/category/
# https://fr-fr.facebook.com//pages/category/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT2My8t4YzT5mbeVV7IgD5tS159IgpBcnV72roo0gm4H4vJFVxNN4xADPrBpi_m6bTGfEi4iH8B8HGvzwRp43cStBzPSDxQsVdsGzeBrhyrhNDswvGjFrQgRosUT5TYFj0BW3Q_usdnnvVL9ccyAvXhlR5orbei1
# https://it-it.facebook.com//pages/category/
# https://ar-ar.facebook.com//pages/category/
# https://de-de.facebook.com//pages/category/
# https://hi-in.facebook.com//pages/category/
# https://zh-cn.facebook.com//pages/category/
# https://ja-jp.facebook.com//pages/category/
# https://pt-br.facebook.com//pages/category/
# https://www.cefetmg.br/instituicao/diretoria-geral/
# https://www.facebook.com//login/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT0_eNM3I728kAvK3AoN4gAtcLV9DOnuIGTC_r8TPNEuhzTQEFf_ozefMJcc2wgD8RsGbVupmfD0a3nME_r0L__p4Wl-krjZIJ_oDDGOaXqTX1MPOmb79dvmbDxvDRIrUZTmoDTKmzaU2L4X2qJv7-bKstDCtnhw
# https://www.cefetmg.br/instituicao/diretorias-especializadas/
# https://www.facebook.com//reg/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT2G3zJNRWo7ce6U53LXiEn0U4K8RyF7wJoCuwb2lG9msWyIo8Ha2buBgEZNwq8Fii7gJyjZo6FvbJalYzTdbKmfs7f5GuSqx-obC1F5onr_1Hrjrhf8p20uY08Aojjrp7n4J2nJwH6iVmapEGfzbu3fXsYCenSM
# https://www.cefetmg.br/noticias/diretoria-de-governanca-e-desenvolvimento-institucional-comeca-a-atuar/
# https://es-la.facebook.com//directory/places/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT33zJn4RSHpvudDIzJ-xsnioCAzQi8-VG9sBPOaeM8yRzREVXKWbiNpUpyJ36Q9eGZj2_NKddhr7Q73zxFEZ8r4klF5-8GBDi13IZhG7jiOXmH2wI3tX87SelSS35thGWIA7MCThx0IHR6hsGyiTxAo8KDTen_u
# https://fr-fr.facebook.com//directory/places/
# https://it-it.facebook.com//directory/places/
# https://ar-ar.facebook.com//directory/places/
# https://de-de.facebook.com//directory/places/
# https://www.cefetmg.br/instituicao/secretarias-especializadas/
# https://hi-in.facebook.com//directory/places/
# https://www.facebook.com/cefetmg/likes?ref=page_internal
# https://es-la.facebook.com//marketplace/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT3edE1490ZKYszDcrLWKUeZBqrUEPbFeHh_3p-1sT-QA1u286stsoUYuIpJ_F5cbxVvLAVxVT9ZH72_-tKMhobqg49SGmSbtSFx1qafEpdgl9aMKZFt1fA7effpgD2WGCvyKbbmn8G9Pe39fsrxU3B3bc4wbE1i
# https://fr-fr.facebook.com//marketplace/
# https://it-it.facebook.com//marketplace/
# https://zh-cn.facebook.com//directory/places/
# https://ja-jp.facebook.com//directory/places/
# https://pt-br.facebook.com//directory/places/
# https://ar-ar.facebook.com//marketplace/
# https://de-de.facebook.com//marketplace/
# https://www.cefetmg.br/instituicao/conselhos/
# https://hi-in.facebook.com//marketplace/
# https://www.facebook.com/cefetmg/likes
# https://es-la.facebook.com//directory/groups/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT1xciCJbHCkU515XBh56RHvR5BGr7DVrHjli8Dkotm4UrdLrrj3mPwlopqoXtRLO8066EfnemqV-r3DznHRh_vTXHUlYhIXof_P1q-1QyZXq2TbBCNioyCha13BIG-Z9xE68IH5j7JbLv-2DqbMaamHoh6P5TjE
# https://fr-fr.facebook.com//directory/groups/
# https://it-it.facebook.com//directory/groups/
# https://zh-cn.facebook.com//marketplace/
# https://ja-jp.facebook.com//marketplace/
# https://pt-br.facebook.com//marketplace/
# https://ar-ar.facebook.com//directory/groups/
# https://de-de.facebook.com//directory/groups/
# https://www.cefetmg.br/instituicao/comissoes-permanentes/
# https://hi-in.facebook.com//directory/groups/
# https://www.facebook.com/cefetcarreiras/?ref=py_c
# https://es-la.facebook.com//local/lists/245019872666104/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT28lOSOSnn6SPRGSU23CBu540GtPjsmIld3XI__MBay3_E7FGjNhrA6zsDb_5UiMqKWxnuAbO5BzG9OEShyksbv0BaT35NvbUaeL3XcHMMsNhcsKntnRJES1rCMTm0dwo7GXkaGhkxqNbjRjbI2iL3NzN8WUuZA
# https://fr-fr.facebook.com//local/lists/245019872666104/
# https://it-it.facebook.com//local/lists/245019872666104/
# https://zh-cn.facebook.com//directory/groups/
# https://ja-jp.facebook.com//directory/groups/
# https://pt-br.facebook.com//directory/groups/
# https://ar-ar.facebook.com//local/lists/245019872666104/
# https://de-de.facebook.com//local/lists/245019872666104/
# https://www.cefetmg.br/instituicao/comissao-permanente-de-pessoal-docente/
# https://hi-in.facebook.com//local/lists/245019872666104/
# https://www.facebook.com/cefetmg.campus.nova.gameleira/?ref=py_c
# https://es-la.facebook.com//fundraisers/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT2ZSD5PlKLVL4rSiyrj4NguJVyXxlJDXgRuWrMJuCxMudpnl8sD83iIUlJSltB_7MOWZu-WAAn_6GaEbSC8_5NYCNWAsqddtv6QLmm9c1oh-IEU-V7UFP6Yo_fhYge84GKng6SeH4GhV0buMXqJOmn2fZH1MJ6Q
# https://fr-fr.facebook.com//fundraisers/
# https://it-it.facebook.com//fundraisers/
# https://zh-cn.facebook.com//local/lists/245019872666104/
# https://ja-jp.facebook.com//local/lists/245019872666104/
# https://pt-br.facebook.com//local/lists/245019872666104/
# https://ar-ar.facebook.com//fundraisers/
# https://de-de.facebook.com//fundraisers/
# https://www.cefetmg.br/instituicao/comissao-interna-de-supervisao-do-plano-de-carreira-dos-tecnico-administrativos-em-educacao/
# https://hi-in.facebook.com//fundraisers/
# https://www.facebook.com/pucminasoficial/?ref=py_c
# https://es-la.facebook.com//biz/directory/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT1r_YGBiJ_B0A-RpfviliOfo5oogDcXzUx6CEBt3AgSl2teHP9GoxwiS4iJ5FJ7hHpJNkMqkpbGoIRlMJRd30xWxPYk3uW-J1T9h8z-WXyF8GCGmOQ9qukKsVmsjUmD4uOqAAXkuYa47y0phTwjiqedToinlWjE
# https://fr-fr.facebook.com//biz/directory/
# https://it-it.facebook.com//biz/directory/
# https://zh-cn.facebook.com//fundraisers/
# https://ja-jp.facebook.com//fundraisers/
# https://pt-br.facebook.com//fundraisers/
# https://ar-ar.facebook.com//biz/directory/
# https://de-de.facebook.com//biz/directory/
# https://www.cefetmg.br/instituicao/comissao-de-iniciacao-cientifica/
# https://hi-in.facebook.com//biz/directory/
# https://www.facebook.com/dce.cefetmg/?ref=py_c
# https://es-la.facebook.com//votinginformationcenter/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT04hg__jJ_4AzDUjHnO3C317vtlim6Hk8CVrw7eEdM47WpwlAHOxc4Oy2cEHyz7iUHmsGQCCb8WWd0JGrPLYWnE7yc8dr95rvlnxkw8Qf0VYcyhji7-dquaJlHICL4QixH__gfmi1lfJoH6dJA22d3r_3MKhmqw
# https://fr-fr.facebook.com//votinginformationcenter/
# https://it-it.facebook.com//votinginformationcenter/
# https://zh-cn.facebook.com//biz/directory/
# https://ja-jp.facebook.com//biz/directory/
# https://pt-br.facebook.com//biz/directory/
# https://ar-ar.facebook.com//votinginformationcenter/
# https://de-de.facebook.com//votinginformationcenter/
# https://www.cefetmg.br/instituicao/campi/
# https://hi-in.facebook.com//votinginformationcenter/
# https://www.facebook.com/centrouniversitarionewtonpaiva/?ref=py_c
# https://es-la.facebook.com//facebook
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=A
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT3dipsyEb5Ptc7qo1gfPXuk9-kxzW9GA1OXXQYI3NMbJY_A86Ymkw0v7Ap7Az_MDm74RuKaM_S08-GsEgj2DXJ7ap6p4Zppah5erulaPHm-f76umDxsTI7IHNLSFVAJ4N9xXl-l0TP6f3wBGKD9cc4Dc9xhdpPZ
# https://fr-fr.facebook.com//privacy/explanation
# ...
# https://fr-fr.facebook.com//careers/
# https://it-it.facebook.com//careers/
# https://ar-ar.facebook.com//careers/
# https://de-de.facebook.com//careers/
# https://hi-in.facebook.com//careers/
# https://zh-cn.facebook.com//careers/
# https://ja-jp.facebook.com//careers/
# https://pt-br.facebook.com//careers/
# https://www.cefetmg.br/graduacao/
# https://www.facebook.com/trincabotzcefetmg/?ref=py_c
# https://es-la.facebook.com//privacy/explanation
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT0polZh9dJGDxFFykZw8H6cJVpMAYmqnFytlwmw4nsm2c0v7M0fVFqJI3nW_LXPxAzec8NKhRYtw3ajiV-bTqeJam3sMerlWf1-okPoo5D4UT9sZFkW6wwQ8NaOmwvBRA0suA1WNqWVTmmzU_wiveskZMxFdMaH
# https://fr-fr.facebook.com//privacy/explanation
# https://it-it.facebook.com//privacy/explanation
# https://ar-ar.facebook.com//privacy/explanation
# https://de-de.facebook.com//privacy/explanation
# https://hi-in.facebook.com//privacy/explanation
# https://zh-cn.facebook.com//privacy/explanation
# https://ja-jp.facebook.com//privacy/explanation
# https://pt-br.facebook.com//privacy/explanation
# https://www.cefetmg.br/pos-graduacao/
# https://www.facebook.com/centrouniversitariounibh/?ref=py_c
# https://es-la.facebook.com//policies/cookies/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT3TqR1TWAjv0L5c8UYewMR1-VdMNsCiWO3lDWqqru9k1E0QW4pQ0O84nfYJMXugmCiElQ6ddgMeMCFesAD0yVU6xeCVkm8gl_AUfuHgIVuCOM8BDWNw7qPYJd0u-tBtiYXVjNdJoZ5kuOIE_ExTolrRyr8R_jmI
# https://fr-fr.facebook.com//policies/cookies/
# https://it-it.facebook.com//policies/cookies/
# https://ar-ar.facebook.com//policies/cookies/
# https://de-de.facebook.com//policies/cookies/
# https://hi-in.facebook.com//policies/cookies/
# https://zh-cn.facebook.com//policies/cookies/
# https://ja-jp.facebook.com//policies/cookies/
# https://pt-br.facebook.com//policies/cookies/
# https://www.cefetmg.br/pesquisa/
# https://www.facebook.com/BibliotecaCampus1CEFETMG/?ref=py_c
# https://es-la.facebook.com/help/568137493302217
# https://www.intern.facebook.com/help/195227921252400?helpref=faq_content
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT2sOSwrY9F4xtoNGEDRw5R6QkflUww55xZx44n07vnJxv-FT9tdzDSivLTK80IsN_IIXw-PZv8qOFSXu2eHXzF36xzm0bgaCAG_7Zv1tk8eFckZKeqB97HvAQ7vOfJrCV1-Xi4k9UykyNnRVImmTE5tx36emdSl
# https://fr-fr.facebook.com/help/568137493302217
# https://it-it.facebook.com/help/568137493302217
# https://ar-ar.facebook.com/help/568137493302217
# https://de-de.facebook.com/help/568137493302217
# https://hi-in.facebook.com/help/568137493302217
# https://zh-cn.facebook.com/help/568137493302217
# https://ja-jp.facebook.com/help/568137493302217
# https://pt-br.facebook.com/help/568137493302217
# https://www.cefetmg.br/pesquisa/coordenacoes/
# https://www.facebook.com/gremiocefetbh/?ref=py_c
# https://es-la.facebook.com//policies
# https://www.intern.facebook.com/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fshare.here.com%2Fr%2Fmylocation%2Fe-%3D%3D%3Flink%3Daddresses%26fb_locale%3Dpt_BR%26ref%3Dfacebook&h=AT0NyEAsdNDS7DNubJeGOk-3JquC-m0jfTnETDav9ZiWT5SuLIsB1tkm2wOyyJq-OeR9zrGv9IyAaQ1xFCNE-XAZqSFH4O4MzekEsswu_yS-lxbsea7i64u_xLvzweKKg4mCObCrTT3TSoD7ibX991N8YhA4lqbv
# https://fr-fr.facebook.com//policies
# https://it-it.facebook.com//policies
# https://ar-ar.facebook.com//policies
# https://de-de.facebook.com//policies
# https://hi-in.facebook.com//policies
# https://zh-cn.facebook.com//policies
# https://ja-jp.facebook.com//policies
# https://pt-br.facebook.com//policies
# https://www.cefetmg.br/editais-e-chamadas-publicas/
# http://www.fulbright.org.br
# https://www.facebook.com/fcm.idiomas/?ref=py_c
# https://es-la.facebook.com//help/
# https://fulbright.org.br/comissao/
# https://www.intern.facebook.com//r.php
# https://www.instagram.com/fulbrightbrasil/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.cefetmg.br%2F&h=AT0XhfeNJHx8_UZQzNiwc36QxVgqdJGhMawD5Kt6RvUcyioZOi-NC_tyO98Gd7a3ECqcoPnJ63S3I7_IAXrFvPZyb27YtYMQvEaQzuz-jSfCosv3-Itq4K33AyyLSAPbnkcVC5v4-75hSgfoXzQTpuwZDah3UV8m
# https://fr-fr.facebook.com//help/
# https://it-it.facebook.com//help/
# https://ar-ar.facebook.com//help/
# https://de-de.facebook.com//help/
# https://hi-in.facebook.com//help/
# https://zh-cn.facebook.com//help/
# https://ja-jp.facebook.com//help/
# https://pt-br.facebook.com//help/
# https://www.cefetmg.br/aluno/
# http://www.fulbright.org.br/
# https://www.facebook.com/feiracefettec/?ref=py_c
# https://es-la.facebook.com//settings
# https://fulbright.org.br/bolsas-para-brasileiros/
# https://www.intern.facebook.com//login/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.cefetmg.br%2F&h=AT2xqkZAiruWHqicNxAPhPFUcZgz_Wk4z0jiHy7cEY8it5Wht6I5DF4wA2Tv3YT31FsmtLYHzoSVfgDp8yUyqnUYTXB7llMBJArt0I-leUCEvjsTRGlPlJDnTh_bQzQRRmhYns7jeaAWR43kdub3w7rpbRvCCgEiHIk
# https://fr-fr.facebook.com//settings
# https://it-it.facebook.com//settings
# https://ar-ar.facebook.com//settings
# https://de-de.facebook.com//settings
# https://hi-in.facebook.com//settings
# https://zh-cn.facebook.com//settings
# https://ja-jp.facebook.com//settings
# https://pt-br.facebook.com//settings
# https://www.cefetmg.br/aluno/servicos/
# https://www.facebook.com/inatel/?ref=py_c
# https://fulbright.org.br/grants-for-us-citizens/
# https://www.intern.facebook.com//lite/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fbit.ly%2F3dqbHLz&h=AT0vYSXlQtUzEjhjNiWvLmtqrMMQBz7zY-bg5uMpWDkavlM0kBmxUeVyxFKzCB4CCTHDRZdcF5a9pvVBttxqIQidDR2Oi53paRcct9ca1vOkmRMVsreSJO2ZkyjCi1zeb4Euv-i8CwAqSl9U9cYJg9RHkWGeuQf9QTMYh83Zj2k4QXc9lDA
# https://www.cefetmg.br/calendario-academico/
# https://www.facebook.com/minhaUFOP/?ref=py_c
# https://es-la.facebook.com/login/identify/?ctx=recover&ars=royal_blue_bar
# https://fulbright.org.br/alumni/
# https://www.intern.facebook.com//directory/people/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fbit.ly%2F3dqbHLz&h=AT1PSUkxm94-o6X1Sti9kySGHXni08Ru2c9Bq1T3eDFThLClzCFM2S6lxNNwXPpWEMGR28Yzomvbcm6vQozlZcKuj4AubAwO-YGKerSCCRk_Nf9PjnURN3YDGiORX7DFdj4fUsgXiSVsIsx_pJ5dP1_k0i341_U_QjpYWPXCx6bGpAq4Z_I
# https://fr-fr.facebook.com/login/identify/?ctx=recover&ars=royal_blue_bar
# https://it-it.facebook.com/login/identify/?ctx=recover&ars=royal_blue_bar
# https://ar-ar.facebook.com/login/identify/?ctx=recover&ars=royal_blue_bar
# https://de-de.facebook.com/login/identify/?ctx=recover&ars=royal_blue_bar
# https://hi-in.facebook.com/login/identify/?ctx=recover&ars=royal_blue_bar
# https://zh-cn.facebook.com/login/identify/?ctx=recover&ars=royal_blue_bar
# https://ja-jp.facebook.com/login/identify/?ctx=recover&ars=royal_blue_bar
# https://pt-br.facebook.com/login/identify/?ctx=recover&ars=facebook_login
# https://www.facebook.com/ChromosOficial/?ref=py_c
# https://es-la.facebook.com/recover/initiate?lwv=301&ars=royal_blue_bar
# https://fulbright.org.br/contato/
# https://www.intern.facebook.com//directory/pages/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fbit.ly%2F3dqbHLz&h=AT0EJXemd3aWZazSxQrDZfJ_6pCOCBS2qOW2-Lw6TjA7E5vHs7Cdduc1G586UtgMEilmm_pQ3Qm4xMp4v-WM9O2_VjGBGwbmHMP1edN1k5Ic25KVloRO2Sr5h_nz3LgEm3touHJ-kXtHf8H3kY-OODeNHnqWWe8QAu6h1uSlX-Sy908D67rpQeihh8II
# https://fr-fr.facebook.com/login/identify/?ctx=recover&ars=facebook_login
# https://it-it.facebook.com/login/identify/?ctx=recover&ars=facebook_login
# https://ar-ar.facebook.com/login/identify/?ctx=recover&ars=facebook_login
# https://de-de.facebook.com/login/identify/?ctx=recover&ars=facebook_login
# https://hi-in.facebook.com/login/identify/?ctx=recover&ars=facebook_login
# https://zh-cn.facebook.com/login/identify/?ctx=recover&ars=facebook_login
# https://ja-jp.facebook.com/login/identify/?ctx=recover&ars=facebook_login
# https://pt-br.facebook.com/recover/initiate?lwv=301&ars=royal_blue_bar
# https://www.cefetmg.br/aluno/setores/
# https://www.facebook.com/institutofederalsudestemg/?ref=py_c
# https://es-la.facebook.com//login.php
# https://fulbright.org.br/helder-alves-de-oliveira-premio-internacional-de-composicao/
# https://www.intern.facebook.com//pages/category/
# http://l.facebook.com/l.php?u=http%3A%2F%2Fshare.here.com%2Fr%2Fmylocation%2Fe-%3D%3D%3Flink%3Ddirections%26fb_locale%3Dpt_BR%26ref%3Dfacebook&h=AT2w1889wFJB3HDYlDO8m84OCCjzt4uRKCvlFiRntcafRG1ei1Dy0CDoeL1q5vrpTef6XD1uh75b7yh5ZuhwEjJr93Kc2mOZzk5zjsP00MZVmuL3PlKlI2HOrLRcXjSXoYXXZlYyVABRoBPYkhGJrAEFGLkk4yvS
# https://fr-fr.facebook.com/recover/initiate?lwv=301&ars=royal_blue_bar
# https://it-it.facebook.com/recover/initiate?lwv=301&ars=royal_blue_bar
# https://ar-ar.facebook.com/recover/initiate?lwv=301&ars=royal_blue_bar
# https://de-de.facebook.com/recover/initiate?lwv=301&ars=royal_blue_bar
# https://hi-in.facebook.com/recover/initiate?lwv=301&ars=royal_blue_bar
# https://zh-cn.facebook.com/recover/initiate?lwv=301&ars=royal_blue_bar
# https://ja-jp.facebook.com/recover/initiate?lwv=301&ars=royal_blue_bar
# https://pt-br.facebook.com//login.php
# https://www.cefetmg.br/aluno/acesso/
# https://www.facebook.com/secretariaderi.cefetmg/?ref=py_c
# https://es-la.facebook.com/login/identify/?ctx=recover&ars=facebook_login
# https://fulbright.org.br/lives-da-fulbright/
# https://www.intern.facebook.com//places/
# https://youtu.be/aEW5It4QvWs
# https://l.facebook.com/l.php?u=https%3A%2F%2Fm.me%2Fcefetmg&h=AT2tTIw1gezVhQO0gQ7NPBFUe9EFE6TaS_LTaYGRlVRenJc72Wq4G7zLcgJWxbUmhgEUmg47yWCxmJrgi2dsHV_XlJsTuLOsIie5oKBmw2946EMIMga3Cpp2atxcJPiKmaypB0LZD75l_qSqpU4_yJzjOiqPiIff
# https://fr-fr.facebook.com//login.php
# https://it-it.facebook.com//login.php
# https://ar-ar.facebook.com//login.php
# https://de-de.facebook.com//login.php
# https://hi-in.facebook.com//login.php
# https://zh-cn.facebook.com//login.php
# https://ja-jp.facebook.com//login.php
# https://pt-br.facebook.com/r.php
# https://www.cefetmg.br/servidor/
# https://www.facebook.com/unifalmgoficial/?ref=py_c
# https://es-la.facebook.com/cefetmg/about/
# https://www.intern.facebook.com//games/
# https://fulbright.org.br/covid-19-atendimento-somente-por-e-mail-na-fulbright/
# https://youtu.be/6imo89UAh6A
# http://l.facebook.com/l.php?u=http%3A%2F%2Fwww.cefetmg.br%2F&h=AT1C-CMJ_b4s3l9dBBV40yfOiwhhonEfChrnO3Y1WmlaRuhq6MyoXBqyUYe7pBNXmWcp5uETVU9J-l_FZ17ib6y1paHjWD5HhLzlkGoRGw8EUVAX2G1-ri8IULDblUqpcffJvCUJTja_FJVFTfvce8n2msmbJz9c
# https://fr-fr.facebook.com/cefetmg/about/
# https://it-it.facebook.com/cefetmg/about/
# https://ar-ar.facebook.com/cefetmg/about/
# https://de-de.facebook.com/cefetmg/about/
# https://hi-in.facebook.com/cefetmg/about/
# https://zh-cn.facebook.com/cefetmg/about/
# https://ja-jp.facebook.com/cefetmg/about/
# https://pt-br.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://www.cefetmg.br/concursos/
# https://www.facebook.com/atleticacefetbh/?ref=py_c
# https://es-la.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://www.intern.facebook.com//directory/places/
# https://fulbright.org.br/pdpi-2020-covid19-coronavirus/
# https://youtu.be/4hJN4IeDwcM
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT3n9ELhgq1g2iWmFUoyJ1oRWGOmshULQ9huPkaGw4R9JLhn00fXIt0LbPaqJJLX7Ki7Em51RHhrL9TuaBXLkYwwqnBQhNf_He8quremXYnkDgFhzMj8Nip9KE-HT69nfJ81rGDpQnIrxzXBlgREwueqI7ofKwfN
# https://fr-fr.facebook.com/r.php
# https://it-it.facebook.com/r.php
# https://ar-ar.facebook.com/r.php
# https://de-de.facebook.com/r.php
# https://hi-in.facebook.com/r.php
# https://zh-cn.facebook.com/r.php
# https://ja-jp.facebook.com/r.php
# https://pt-br.facebook.com//legal/terms/update
# https://www.cefetmg.br/concursos/professor-efetivo/
# https://www.facebook.com//browse/fanned_pages/
# https://es-la.facebook.com//legal/terms/update
# https://www.intern.facebook.com//marketplace/
# https://fulbright.org.br/noticias/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT2hVZF8UCzpjyv2AhbNPPZK8QtBdaxMUnhASavIitfMyzWYPiUImS7JPRWLqjIjzf16CjY42meLg2fOQl5Dc83cgwTlxX99I7TO8CxStKhnmBPQNH4eXDPgR8wWehRt9tNQ1CmpKKgDI-L7uXHtZojGNAhsyDto
# https://fr-fr.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://it-it.facebook.com//legal/terms/update
# https://ar-ar.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://de-de.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://hi-in.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://zh-cn.facebook.com//legal/terms/update
# https://ja-jp.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://pt-br.facebook.com//about/privacy/update
# https://www.cefetmg.br/concursos/tecnico-administrativo-em-educacao/
# https://www.facebook.com/pet.ambiental.cefetmg/
# https://es-la.facebook.com//about/privacy/update
# https://www.intern.facebook.com//directory/groups/
# https://fulbright.org.br/parceiros/
# https://www.mec.gov.br/
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT05I07BO6PfGfgYsD8ILqUAWNnO5fCNvv5X9uV2idTLO-atnt8vIYiw9k3bYszWaZlnB6ZoixC5nuytACJoCGWzcG8abp2bwmkU4oCVpBq-H_cwH1ZZ_GsK0wnfbH9tXME8F5LjIUqrC2KzNXu8G1G52dEs4Ezd
# https://fr-fr.facebook.com//legal/terms/update
# https://it-it.facebook.com//about/privacy/update
# https://ar-ar.facebook.com//legal/terms/update
# https://de-de.facebook.com//legal/terms/update
# https://hi-in.facebook.com//legal/terms/update
# https://zh-cn.facebook.com//about/privacy/update
# https://ja-jp.facebook.com//legal/terms/update
# https://pt-br.facebook.com/login/
# https://www.cefetmg.br/acesso-a-informacao/
# https://www.facebook.com/trincabotzcefetmg/
# https://www.cuny.edu/
# https://es-la.facebook.com/r.php
# https://www.intern.facebook.com//local/lists/245019872666104/
# https://fulbright.org.br/f-a-q/
# https://www.mec.gov.br//
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT2y3CgZPF9mWVzYgitUXJYGKhkZ2kaAvugI1_ajUCy596zUzY1Mwblh4xMKoUgVpyPFxKWgzjw8PmqaaGA1emwKqR_TVF2mZiRy9yJfGRjJ-fsQWV3GqfwWByMcG2PuSWW5wqTQ8cKySaS8lLCSJ_X-NP2RbjDc
# https://fr-fr.facebook.com//about/privacy/update
# https://it-it.facebook.com/cefetmg/reviews/
# https://ar-ar.facebook.com//about/privacy/update
# https://de-de.facebook.com//about/privacy/update
# https://hi-in.facebook.com//about/privacy/update
# https://zh-cn.facebook.com/cefetmg/reviews/
# https://ja-jp.facebook.com//about/privacy/update
# https://pt-br.facebook.com/lite/
# https://www.cefetmg.br/acesso-a-informacao/carta-de-servicos-ao-cidadao/
# https://www.facebook.com/EquipeEcofet/
# https://www.cuny.edu/emergencyfund/
# https://es-la.facebook.com/cefetmg/reviews/
# https://www.intern.facebook.com//fundraisers/
# https://fulbright.org.br/privacidade/
# https://www.mec.gov.br//accessibility-info
# https://l.facebook.com/l.php?u=https%3A%2F%2Fwww.instagram.com%2F&h=AT2ehpqsDibF9oUWT68gV-fFjqihCFkZs1SYq0qxSUO-gvtlOXJ-smzb3Swcbs-it-oaEiocHpuydecuuxQp-2LAdYwyGwwAPK8w7nVKNBJYXRyN53rHbCrVW-pyGc3LfMnGEz18zPqGM5arzybDpAGy1BAzbAtJ
# https://fr-fr.facebook.com/cefetmg/reviews/
# https://it-it.facebook.com/login/
# https://ar-ar.facebook.com/cefetmg/reviews/
# http://www4.planalto.gov.br/legislacao
# https://de-de.facebook.com/cefetmg/reviews/
# https://hi-in.facebook.com/cefetmg/reviews/
# https://zh-cn.facebook.com/login/
# https://ja-jp.facebook.com/cefetmg/reviews/
# https://pt-br.facebook.com//sideload/lite/download/
# http://portal.mec.gov.br/index.php?option=com_agendadirigentes&view=autoridadesdetalhamento&filter_categoria=457&Itemid=1333
# https://www.instagram.com/mineducacao/
# https://www.cefetmg.br/acesso-a-informacao/compras/
# https://www.facebook.com/CefastAerodesign/
# https://www.cuny.edu/coronavirus/
# https://www.twitter.com/mec_comunicacao
# https://es-la.facebook.com/login/
# https://enem.inep.gov.br/
# https://www.intern.facebook.com//biz/directory/
# https://fulbright.org.br
# https://www.mec.gov.br//mec/pt-br/acesso-a-informacao/institucional/competencias
# Done - 100

# %%
list_pages_per_sec = []
for i in range(len(list_diff)):
    list_pages_per_sec.append(500/list_diff[i])

table_threads = pd.DataFrame({'Threads' : ["10", "30", "50", "70", "90", "100"],
                   'Start' : list_start,
                   'End': list_end,
                   'Diff' : list_diff,
                    'Pages per Second': list_pages_per_sec
                       })

table_threads
# Out:
#   Threads                      Start                        End         Diff  \
# 0      10 2020-10-16 12:40:21.300496 2020-10-16 13:07:00.150439  1598.849943
# 1      30 2020-10-16 13:07:00.150674 2020-10-16 13:35:43.154628  1723.003954
# 2      50 2020-10-16 13:35:43.155104 2020-10-16 14:02:46.019925  1622.864821
# 3      70 2020-10-16 14:02:46.020252 2020-10-16 14:29:11.768272  1585.748020
# 4      90 2020-10-16 14:29:11.769276 2020-10-16 14:55:39.315493  1587.546217
# 5     100 2020-10-16 14:55:39.315781 2020-10-16 15:22:05.571214  1586.255433
#
#    Pages per Second
# 0          0.312725
# 1          0.290191
# 2          0.308097
# 3          0.315309
# 4          0.314951
# 5          0.315208

# %%
list_pages_per_sec = []
for i in range(len(list_diff)):
    list_pages_per_sec.append(500/list_diff[i])

table_threads = pd.DataFrame({'Threads' : ["10", "30", "50", "70", "90", "100"],
                   'Start' : list_start,
                   'End': list_end,
                   'Diff' : list_diff,
                    'Pages per Second': list_pages_per_sec,
                       })

table_threads
# Out:
#   Threads                      Start                        End        Diff  \
# 0      10 2020-10-11 00:57:06.976505 2020-10-11 00:59:56.885040  169.908535
# 1      30 2020-10-11 00:59:56.885385 2020-10-11 01:02:51.714986  174.829601
# 2      50 2020-10-11 01:02:51.715447 2020-10-11 01:05:29.517582  157.802135
# 3      70 2020-10-11 01:05:29.517868 2020-10-11 01:08:38.010082  188.492214
# 4      90 2020-10-11 01:08:38.010330 2020-10-11 01:11:12.391894  154.381564
# 5     100 2020-10-11 01:11:12.392143 2020-10-11 01:13:45.271739  152.879596
#
#    Pages per Second
# 0          0.588552
# 1          0.571986
# 2          0.633705
# 3          0.530526
# 4          0.647746
# 5          0.654110

# %% [markdown]
# # Bibliografia
#
# Baeza-Yates, Ricardo; Ribeiro-Neto, Berthier. **Modern information retrieval: the concepts and technology behind search**. ACM Press, 2011.
#
# Batista, Natércia ; Brandão, Michele ; Pinheiro, Michele ; Dalip, Daniel ; Moro, Mirella . **[Dados de Múltiplas Fontes da Web: coleta, integração e pré-processamento](https://sol.sbc.org.br/livros/index.php/sbc/catalog/download/8/19/58-1?inline=1)**. Minicursos do XXIV Simpósio Brasileiro de Sistemas Multimídia e Web. 1ed.: Sociedade Brasileira de Computação, 2018, v. , p. 153-192.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# gca stands for 'get current axis'
ax = plt.gca()

table_threads.plot(kind='line',x='Threads',y='Pages per Second',ax=ax)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# gca stands for 'get current axis'
ax = plt.gca()

table_threads.plot(kind='line',x='Threads',y='Diff',ax=ax)

plt.show()
