# %% [markdown]
# Nesta prática você irá implementar o indexador para, logo após, indexar o conteúdo da Wikipédia. Nesta prática, o índice é composto pela classe abstrata `Index` que armazena a estrutura do índice e possui as operações básicas do mesmo.
#
# Iremos fazer duas implementações desse índice: o `HashIndex` que será um índice simples em memória principal e o `FileIndex` em que as ocorrências ficarão em memória secundária para possibilitar a indexação de uma quantidade maior de páginas. Assim, teremos os seguintes arquivos:
#
# - `structure.py`: Possui toda a estrutura do índice;
# - `index_structure_test.py`: Testa a estrutura do índice;
# - `file_index_test.py`: Possui os testes unitários específicos para a indexação das ocorrencias em arquivos da classe `FileIndex`;
# - `performance_test.py`: Executa um teste de performance (tempo de execução e memória utilizada) do índice;
# - `indexer.py`: Possui as classes para o preprocessamento e preparação para a indexação;
# - `indexer_test.py`: Realiza o [teste de integração](https://en.wikipedia.org/wiki/Integration_testing) da prática como um todo (inclusive as funções da indexer.py).
#
# Na entrega, não esqueça de apresentar a saída de execução de cada atividade desta tarefa.

# %% [markdown]
# ## Implementação da classe Abstrata `Index` e classe `HashIndex`

# %% [markdown]
# A classe abstrata Index, no arquivo `structure.py` possui os seguintes atributos:

# %% [markdown]
# - `dic_index`:  dicionário em que a chave é o termo indexação (string, gerenciado por esta classe) e, os valores,  podem der de diferentes tipos - dependendo da subclasse;
# - `set_documents`: conjunto de ids de documentos existentes.

# %% [markdown]
# Os métodos serão discutidos ao longo das atividades. Inicialmente, iremos fazer a importação do módulo:

# %%
from index.structure import *

# %% [markdown]
# **Atividade 1 - método index da classe Index**: Este método esta quase todo pronto e é reponsável por indexar um termo com sua frequncia e documento no índice, de acordo com uma de suas subclasses. Você deve deve apenas inicializar a variável `int_term_id` apropriadamente - substituindo os `None` correspondente. Caso o termo não exista no índice, deverá obter o próximo term_id. Esse id pode ser sequencial. Caso esse id seja encontrado, a classe Index deverá chamar o método `get_term_id` (implementado pelas subclasses) para obtê-lo pois, dependendo da implementação, haverá uma forma diferente de obtenção. Além disso, você deverá atualizar o atributo `set_documents` apropriadamente. Para testar tanto esta atividade e a seguinte,  você deverá fazer uma das implementações dessa classe - a classe **HashIndex** - na atividade 3.

# %% [markdown]
# **Atividade 2 - atributos calculados da classe Index**: Você deve implementar os atributos calculados `document_count` e `vocabulary` da classe Index. O atributo `document_count` retorna a quantidade de documentos existentes e, `vocabulary` retorna uma lista com o vocabulário completo indexado.

# %% [markdown]
# **Atividade 3 - Implementação da classe HashIndex: ** O HashIndex deverá fazer um índice em memória.
#
# Como exemplo, caso tenhamos três documentos $d_1 = $"A casa verde é uma casa bonita", $d_2 = $"A casa bonita" e $d_3 =$"O prédio verde", caso não haja remoção de _stopwords_ nem acentos, o atributo `dic_index` deverá possuir a seguinte estrutura:

# %%
{"a": [TermOccurrence(1,1,1), TermOccurrence(2,1,1)],
 "casa": [TermOccurrence(1,2,2), TermOccurrence(2,2,1)],
 "verde": [TermOccurrence(1,3,1), TermOccurrence(3,3,1)],
 "é": [TermOccurrence(1,4,1)],
 "uma": [TermOccurrence(1,5,1)],
 "bonita": [TermOccurrence(1,6,1),TermOccurrence(2,6,1)],
 "o": [TermOccurrence(3,7,1)],
 "prédio": [TermOccurrence(3,8,1)]
}

# %% [markdown]
# Por simplicidade deste indice, perceba que deixamos o `term_id` de forma repetida. Iremos deixar assim, porém poderiamos retirar essa redundancia para reduzir o consumo de memória. Nesta prática, iremos implementar o índice em arquivo que irá ser melhor ainda na questão de consumo de memória ;)

# %% [markdown]
# O índice é chamado da seguinte forma - esse código só ira funcionar depois que vocẽ terminar esta atividade :):

# %%
index = HashIndex()
#indexação do documento 1
index.index("a",1,1)
index.index("casa",1,2)
index.index("verde",1,1)
index.index("é",1,1)
index.index("uma",1,1)
#indexação do documento 2
index.index("a",2,1)
index.index("casa",2,1)
index.index("bonita",2,1)

#indexação do documento 3
index.index("o",3,1)
index.index("prédio",3,1)
index.index("verde",3,1)

index.finish_indexing()

# %%
if "casa" not in index.dic_index:
    print("oi")
else:
    print(index.dic_index["casa"])
print(len([]))

# %% [markdown]
# A classe `Index` é que irá manter o dicinário com o vocabulário do índice e, dependendo de sua implementação, suas ocorrencias. Iremos fazer duas implementações: a classe `HashIndex`, que faz o indice e suas ocorrencias em memória principal e a classe `FileIndex`, que armazena as ocorrências em arquivo, ambas subclasses de `Index`. O método `finish_indexing` é um método que não está implementado no `Index` e é implementado (opcionalmente) nas suas subclasses caso haja necessidade de fazer algo no final da indexação. Em nosso caso, apenas a classe `FileIndex` irá precisar.

# %% [markdown]
# Agora, você deverá implementar a classe HashIndex. Para sua implementação, você deverá completar os seguintes métodos/atributo calculados:
# - `create_index_entry`: cria uma nova entrada no índice utilizando, se necessário, o id do termo passado como parâmetro - não será necessário agora. A implementação deste método é **super simples** - apenas substitua o None. Verifique também o método `index` da superclasse para entender melhor o que será retornado;
# - `add_index_occur`: Adiciona uma nova ocorrencia na entrada deste índice. Você precisará da entrada do termo atual, o id do documento e frequencia do termo no documento, passado como parâmetro. Atualize substituindo os `None`. Veja também o modo `index` da superclasse para entender melhor como o método funciona.
#
# Faça os testes baixo para garantir que a atividade atual e as duas anteriores foram implementadas corretamente. Nos primeiros dois testes, você ainda não verá a lista de ocorrências, pois o método para obtê-la será implementado a seguir.

# %%
# !python3 -m index.index_structure_test StructureTest.test_vocabulary

# %%
# !python3 -m index.index_structure_test StructureTest.test_document_count

# %% [markdown]
# Agora, implemente os métodos:

# %% [markdown]
# - `get_occurrence_list`: Retornará a lista de ocorrencias de um determinado termo. Considerando o exemplo apresentado no inicio desta atividade, `index.get_occurrence_list('casa')` retornará a lista `[TermOccurrence(1,2,2), TermOccurrence(2,2,1)]`. Caso um termo não exista, este método deverá retornar uma lista vazia. Logo após, execute o teste abaixo:

# %%
# !python3 -m index.index_structure_test StructureTest.test_get_occurrence_list

# %% [markdown]
# - `document_count_with_term`: Retorna a quantidade de documentos que possuem um determinado termo. Considerando o exemplo apresentado no inicio desta atividade, `index.document_count_with_term('casa')` retornará 2. Caso um termo não exista, este método deverá retornar zero. Logo após, execute o teste abaixo:

# %%
# !python3 -m index.index_structure_test StructureTest.test_document_count_with_term

# %% [markdown]
# **Atividade 4 - métodos de comparação da classe TermOccurrence**: Eventualmente iremos precisar ordenar as ocorrências Por isso, temos que implementar os [comparadores de `__eq__` e `__lt__`](https://docs.python.org/3.7/reference/datamodel.html#object.__lt__) além de usar o _decorator_ [total_ordering](https://docs.python.org/3.7/library/functools.html#functools.total_ordering) - [veja também aqui](https://portingguide.readthedocs.io/en/latest/comparisons.html#rich-comparisons). `__eq__` retorna igual se um objeto é considerado igual ao outro. Considere que uma ocorrencia é igual a outra se o id do termo dela e o id do documento forem iguais.
#
# O comparador `<` é implementado pelo método `__lt__` que retorna verdadeiro sde o objeto corrrente `self` é menor do que o objeto passado como parametro. A ocorrencia deverá ser ordenada primeiramente pelo seu `term_id` e, logo após, pelo `doc_id`. Faça o exemplo abaixo para testar (não esqueça de reiniciar o Kernel quando modificar o código):

# %%
from index.structure import *

# %%
t1 = TermOccurrence(1,1,2)
t2 = TermOccurrence(3,1,2)
t3 = TermOccurrence(1,2,2)
t4 = TermOccurrence(2,2,2)
t5 = TermOccurrence(2,2,2)


print(f"Resultado obtido: {t1 == t5} - esperado: True")
print(f"Resultado obtido: {t1 != t1} - esperado: False")
print(f"Resultado obtido: {t1 == None} - esperado: False")
print(f"Resultado obtido: {t1 < t2} - esperado: True")
print(f"Resultado obtido: {t2 > t3} - esperado: False")
print(f"Resultado obtido: {t3 < t4} - esperado: True")
print(f"Resultado obtido: {t2 > t4} - esperado: False")
print(f"Resultado obtido: {t2 > None} - esperado: False")
print(f"Resultado obtido: {t2 < None} - esperado: True")
# Out:
# Resultado obtido: False - esperado: True
# Resultado obtido: False - esperado: False
# Resultado obtido: False - esperado: False
# Resultado obtido: True - esperado: True
# Resultado obtido: False - esperado: False
# Resultado obtido: True - esperado: True
# Resultado obtido: False - esperado: False
# Resultado obtido: False - esperado: False
# Resultado obtido: True - esperado: True

# %% [markdown]
# ## Construção de índice usando arquivo

# %% [markdown]
# A construção de índice usando apenas memória principal fácil de implementar e eficiente em termos de tempo de execução. Porém, quando precisamos de indexar milhões/bilhões de páginas, é muitas vezes inviável armazenarmos tudo em memória principal.
#
# Para resolver esse problema, uma solução é mantermos o vocabulário em memória principal e as ocorrências em memória secundária. Assim, teriamos o mesmo atributo `dic_index` na classe `Index`. Porém, cada entrada (termo) referenciará as ocorrencias em arquivo. Utilizando exemplo da atividade 3 neste contexto, no final da indexação, o `dic_index` deve ficar da seguinte forma:

# %%
{"a": TermFilePosition(1, 0, 2), 
 "casa": TermFilePosition(2, 20, 2), 
 "verde": TermFilePosition(3, 40, 2),
 "é": TermFilePosition(4, 60, 1), 
 "uma": TermFilePosition(5, 70, 1), 
 "bonita": TermFilePosition(6, 80, 2), 
 "o": TermFilePosition(7, 100, 1), 
 "prédio": TermFilePosition(8, 110, 1), 
}
# Out:
# {'a': term_id: 1, doc_count_with_term: 2, term_file_start_pos: 0,
#  'casa': term_id: 2, doc_count_with_term: 2, term_file_start_pos: 20,
#  'verde': term_id: 3, doc_count_with_term: 2, term_file_start_pos: 40,
#  'é': term_id: 4, doc_count_with_term: 1, term_file_start_pos: 60,
#  'uma': term_id: 5, doc_count_with_term: 1, term_file_start_pos: 70,
#  'bonita': term_id: 6, doc_count_with_term: 2, term_file_start_pos: 80,
#  'o': term_id: 7, doc_count_with_term: 1, term_file_start_pos: 100,
#  'prédio': term_id: 8, doc_count_with_term: 1, term_file_start_pos: 110}

# %% [markdown]
# e as ocorrencias, ordenadas por termo e, logo após, por documento ficariam em um arquivo na seguinte ordem:

# %%
[TermOccurrence(1,1,1), 
 TermOccurrence(2,1,1), 
 TermOccurrence(1,2,2), 
 TermOccurrence(2,2,1),
 TermOccurrence(1,3,1), 
 TermOccurrence(3,3,1),
 TermOccurrence(1,4,1),
 TermOccurrence(1,5,1),
 TermOccurrence(1,6,1),
 TermOccurrence(2,6,1),
 TermOccurrence(3,7,1),
 TermOccurrence(3,8,1)]

# %% [markdown]
# em que cada instancia da classe `TermFilePosition` é a especificação da posição inicial de um `term_id` em um arquivo  além de especificar também a quantidade de ocorrencias desse termo. Essa posição inicial e quantidade são definidas nos atributos atributos `term_file_start_pos` e `doc_count_with_term`, respectivamente. A posição inicial está em bytes e, nesse exemplo, foi considerado que cada TermOcurrence possui 10 bytes. Assim, por exemplo, o termo casa (term_id=2) inicia-se na posição 20 e possui duas ocorrências. Com isso, é possível obter todas as ocorrencias de um determinado termo.

# %% [markdown]
# Para deixarmos a estrutura dessa forma, temos um dificultador: no arquivo, temos que ordenar as ocorrencias pelo termo, porém, indexamos por documento (veja na atividade 3). Assim, se gravássemos as ocorrências assim que indexarmos, as gravariamos agrupadas por documento.

# %% [markdown]
# Assim, temos que garantir uma ordenação por termo do arquivo externo, lembrando que nem sempre é possível armazenar todo o arquivo em memória principal. Para resolvermos isso, faremos o seguinte:

# %% [markdown]
# - Sempre, ao indexar, salvaremos o indice em uma lista (temporária) de ocorrencia de termos `lst_occurrences_tmp`
# - Usaremos o método `save_tmp_occurrences` para, assim que a lista estiver com um determinado tamanho, ordená-la pelo termo e salvar de formar ordenada em um novo arquivo de indice com a todas as ocorrencias. Para que seja feito isso, você deverá fazer uma ordenação externa lendo m consideração o índice em arquivo atual e a lista de ocorrencias temporárias. Segue o passo a passo:
#     - (1) ordene a lista `lst_occurrences_tmp`. Lembre-se que você implementou os comparadores das instancias TermOccurrence, assim, a ordenação e descobrir o menor valor entre as ocorrencias é uma operação simples;
#     - (2) criar um arquivo novo;
#     - (3) compare a primeira posição da lista com a primeira posição do arquivo de índice, sempre inserindo a ocorrencia considerada com o menor entre elas no novo arquivo. Lembrando novamente que os comparadores foram implementados e que você possui os métodos `next_from_list` e `next_from_file` - que será implementado na atividade 5(b) para ajudar;
#     - (4) esse novo arquivo passará a ser o índice. Exclua o indice antigo e limpe a lista de ocorrencias `lst_occurrences_tmp`.
# - O método `finish_indexing` é o método que será chamado ao finalizar a indexação. Neste contexto ele será usado para organizar o `dic_index` atualizando os atributos `term_file_start_pos` e `doc_count_with_term` para os valores corretos.
#
# Na primeira execução, não haverá arquivo e você adicionará a lista toda no arquivo de forma sequencial. Fazendo esse procedimento, você sempre irá garantir um arquivo ordenado da forma esperada.

# %% [markdown]
# **Atividade 5(a) - método de escrita no arquivo:** Iremos necessitar, em algum momento, a escrita de uma instancia de `TermOccurrence` em arquivo. Assim deveremos implementar o método de escrita em arquivo nessa classe. Para economizar espaço e por simplicidade, será escrito em um arquivo binário armazenando os três atributos inteiros. Cada inteiro será armazenado em 4 bytes - será o suficiente para a nossa indexação. Veja um exemplo abaixo de escrita, leitura e impressão do posicionamento no arquivo (esses métodos serão uteis nessa e nas próximas atividades).

# %%
import os

# Teste de leitura e escrita em arquivos
x = 100
z = 200
with open("arquivo_teste.idx","wb") as file:
    file.write(x.to_bytes(4,byteorder="big"))
    file.write(z.to_bytes(4,byteorder="big"))
with open("arquivo_teste.idx","rb") as file:
    print(f"número: {int.from_bytes(file.read(4),byteorder='big')}")
    print(f"número: {int.from_bytes(file.read(4),byteorder='big')}")
    
os.remove("arquivo_teste.idx")

# %%
from index.structure import *

# Teste remoção do primeiro item da lista
x = TermOccurrence(1,2,3)
y = TermOccurrence(1,2,4)
z = TermOccurrence(2,1,1)
w = TermOccurrence(3,2,1)
L = [x,w,z,y]
print(L.pop(0))

# %% [markdown]
# **Atividade 5(b) - métodos next_from_file e next_from_list**: Antes de fazer a ordenação, é interessante implementar esses dois métodos que irão auxiliar na obtenção do menor elemento no arquivo e na lista, respectivamente. Considerando que a lista e o arquivo estão ordenados de forma crescente, temos que obter o primeiro elemento da lista e retirá-lo (utilize o [método pop](https://docs.python.org/3.1/tutorial/datastructures.html)).
#
# Para a leitura do arquivo, iremos usar a API [pickle](https://docs.python.org/3/library/pickle.html) que facilita inserir/carregar estruturas em arquivo binário. O método `next_from_file` já possui um arquivo aberto e você deverá ler a próxima entrada por meio da função `load` da API `pickle`. Caso não exista próximo elemento, é lançado uma exceção. Em ambos os métodos, caso não exista próximo elemento, será retonado `None`.
#
# Complete a implementação substituindo os `None` quando julgar necessário.

# %% [markdown]
# **Atividade 7 - método save_tmp_occurrences: ** Implemente o método `save_tmp_occurrences`. Esse método deverá salvar a lista `lst_occurrences_tmp` em arquivo de forma ordenada, conforme explicado anteriormente. Neste método, você não precisa preocupar com o atributo `dic_index`. Leve em consideração os seguintes atributos/métodos:
#
# - `idx_file_counter`:  No código, você irá criar sempre novos indices, excluindo o antigo. Este atributo será útil para definirmos o nome do arquivo do índice. O novo arquivo do índice chamará `occur_index_X` em que $X$ é o número do mesmo.
# - `str_idx_file_name`: Atributo que armazena o arquivo indice atual. A primeira vez que executarmos `save_tmp_occurrences` não haverá arquivo criado e, assim `str_idx_file_name = None`
# - `lst_occurrences_tmp`: Lista de ocorrencias a serem armazenadas em arquivo
# - `next_from_file` e `next_from_list`: implementados na atividade anterior, para obter o proximo item do arquivo ou da lista. Importantes para fazer a ordenação.

# %%
s="occur_index_file_1"
print(s[17:])

# %% [markdown]
# Execute o teste unitário abaixo para verificar corretude deste código:

# %%
# !python3 -m index.file_index_test FileIndexTest.test_save_tmp_occurrences

# %% [markdown]
# **Atividade 8: método finish_indexing: ** Agora, com as ocorrências organizadas no arquivo por termo, você deverá implementar o método `finish_indexing` para atualizar o atributo `dic_index` com a posição inicial e quantidade de documentos de cada termo nas suas instancias `TermFilePosition`. Logo após, execute o teste unitário abaixo.

# %%
# !python3 -m index.file_index_test FileIndexTest.test_finish_indexing

# %% [markdown]
# **Atividade 9 - implementação em `FileIndex` dos métodos abstratos da classe Index: ** Como vocês perceberam, `FileIndex` é subclasse de `Index`. Assim,  precisamos implementar os métodos abstratos da classe `Index`:
#
# - `create_index_entry`: no `FileIndex` para criar uma nova entrada no índice, você deverá retornar uma instancia de `TermFilePosition` para este novo `term_id`. Ao criá-lo, você não precisa de definir a posição inicial do arquivo nem a quantidade de documentos. Conforme vocês implementaram nas atividades anteriores, isso é feito apenas no momento de finalização da indexação;
# - `add_index_occur`: Neste caso, você deverá criar e adicionar uma nova ocorrencia na lista de ocorrencias temporárias `lst_occurrences_tmp` e, caso senha passado o limite `FileIndex.TMP_OCCURRENCES_LIMIT` do número máximo de ocorrencias na lista, chamar o método `save_tmp_occurrence`.
# - `get_occurrence_list` e `document_count_with_term`: Possuem as mesmas funcionalidades descritas na atividade 3, porém, agora você deverá considerar a estrutura criada no `FileIndex`. Lembrem-se que esse método é só chamado após a finalização da indexação, assim, considere que o índice já está pronto.

# %% [markdown]
# **Atividade 10 - Teste unitário** Dessa vez, você deverá alterar uma classe de teste unitário para conseguir executá-la.
#
# Agora iremos testar os métodos get_occurrence_list e document_count_with_term. Lembre-se que já temos um teste unitário para isso, porém ele testa a estrutura de um `HashIndex`. Neste caso, iremos apenas mudar a estrutura, mas os métodos serão o mesmo, por isso, conseguiremos reaproveitar o teste feito anteriormente criando apenas uma nova classe de teste.
#
# Implementando este teste, você perceberá como é lindo usar orientação objetos ao seu favor 🥰. No arquivo `index_structure_test.py` você possui a classe `FileStructureTest` que é subclasse de nosso teste criado `StructureTest`.  Você deverá implementar o método `setUp` na classe `FileStructureTest` que sobrepõe o método de mesmo nome na classe `StructureTest`. O método `setUp` é executado sempre antes do teste. Este método que você irá criar irá fazer exatamente a mesma coisa que o criado em `StructureTest` porém, você deverá instanciar um `FileIndex` ao invés de um `HashIndex`. Logo após, execute os testes:

# %%
# !python3 -m index.index_structure_test  FileStructureTest.test_document_count_with_term

# %%
# !python3 -m index.index_structure_test  FileStructureTest.test_get_occurrence_list

# %% [markdown]
# De forma similar, também criamos um teste de performance. Verifique a performance da indexação em arquivo e em memória ao indexar milhões de ocorrencias de termos utilizando os testes abaixo. Note que, desta vez, estamso chamando os testes por meio de comandos Python e não pelo terminal. Assim, caso queira fazer alguma alteração no arquivos `.py`, você deve reiniciar o kernel.

# %% [markdown]
# - Índice completamente em memória principal:

# %%
import unittest
from index.performance_test import PerformanceTest

PerformanceTest.NUM_DOCS = 2500
PerformanceTest.NUM_TERM_PER_DOC = 500

suite = unittest.TestLoader().loadTestsFromTestCase(PerformanceTest)
unittest.TextTestRunner(verbosity=2).run(suite)

# %% [markdown]
# - Índice com ocorrencias em memória secundária. Veja que, abaixo, que você pode ajustar o parametro de número de ocorrências em memória. Será muito útil para não gastar tanto tempo ao indexar o conteúdo da Wikipédia.

# %%
import unittest
from index.performance_test import FilePerformanceTest,PerformanceTest
from index.structure import FileIndex

PerformanceTest.NUM_DOCS = 2500
PerformanceTest.NUM_TERM_PER_DOC = 500
FileIndex.TMP_OCCURRENCES_LIMIT = 10000

suite = unittest.TestLoader().loadTestsFromTestCase(FilePerformanceTest)
unittest.TextTestRunner(verbosity=2).run(suite)

# %% [markdown]
# ## Indexador de HTML

# %% [markdown]
# Agora, você irá alterar o arquivo `indexer.py` para [preprocessar conteúdo HTML](https://docs.google.com/presentation/d/1C22jQWIYobiqMx8SmP1y2lr1uSlvJSu3ayu5lXC5d8A/edit?usp=sharing) e depois indexá-lo. Com isso, você poderá usá-lo para indexação das páginas HTML, como os da Wikipédia. A classe `Cleaner` será responsável pelo preprocessamento e a HTMLIndexer, para a indexação.

# %%
from index.indexer import *
#importamos o módulo structure
#novamente para não precisar de executar o código do início da tarefa
from index.structure import *
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/antonioaads/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# **Atividade 11 - Limpeza dos dados com a classe Cleaner: ** A classe `Cleaner` é responsável por preprocessar o conteúdo HTML para que ele esteja preparado para indexação. Essa classe tem alguns _flags_ para definir se algum tipo de processamento opcional será feito (por exemplo, _stemming_ e remoção de _stopwords_). Para isso, você deverá implementar pequenos métodos para fazer a limpeza. Esses códigos são pequenos pois temos lindas APIs para nos ajudar 💕. Você irá fazer o processamento básico e, se quiser, pode melhorar a implementação criando exceções na remoção de acentos e não retirando maiúsculas e minúsculas de certas palavras e unindo palavras compostas, por exemplo.

# %% [markdown]
# Para cada tarefa, há um método para ser criado a seguir os testes iniciais serão feitos aqui no Jupyter. Não esqueça de reiniciar o kernel sempre que alterar algo no código. Logo após, haverá um [teste de integração](https://en.wikipedia.org/wiki/Integration_testing) para avaliar a indexação como um todo.
#
# - **Transformação de HTML para texto: ** Na limpeza dos dados, iremos remover tudo que não será indexado - ou seja, o código HTML. Para isso, iremos implementar o método `html_to_plain_text` que transformará o HTML em texto corrido. Você pode utilizar o [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) para isso e o método get_text.

# %%
cleaner_test = Cleaner(stop_words_file="stopwords.txt",
                        language="portuguese",
                        perform_stop_words_removal=True,
                        perform_accents_removal=True,
                        perform_stemming=True)
cleaner_test.html_to_plain_text("&copy; oi! Meu nome é <strong>Hasan</strong>")
#esperado: '© oi! Meu nome é Hasan'
# Out:
# '© oi! Meu nome é Hasan'

# %% [markdown]
# - **Verifica se é stopword**: O método `is_stopword` retorna verdadeiro se uma palavra, passada como parâmetro, é stopword. Para isso, você irá usar o atributo `set_stop_words`. Este atibuto foi inicializado com um conjunto de stopwords de um arquivo. Esse arquivo, para testes, tem poucas stopwords.

# %%
print(f"{cleaner_test.is_stop_word('japão')}, esperado: False")
print(f"{cleaner_test.is_stop_word('cama')}, esperado: False")
print(f"{cleaner_test.is_stop_word('é')}, esperado: True")
# Out:
# False, esperado: False
# False, esperado: False
# True, esperado: True

# %% [markdown]
# - **Stemming**: você deverá implementar o método word_stem para ralizar o stemming. Você deverá usar a [classe SnowballStemmer da API NLTK](https://www.nltk.org/howto/stem.html). Um objeto dessa classe já está instanciado no atributo `stemmer`.

# %%
print(f"{cleaner_test.word_stem('verdade')}, esperado: verdad")
print(f"{cleaner_test.word_stem('estudante')}, esperado: estud")
print(f"{cleaner_test.word_stem('amado')}, esperado: amad")
# Out:
# verdad, esperado: verdad
# estud, esperado: estud
# amad, esperado: amad

# %% [markdown]
# - **Remoção de acentos:** Iremos fazer de uma forma bem simples a remoção de acentos: aplicando uma tabela de substituição de caracteres. Para isso, você deverá criar uma [tabela de tradução](https://docs.python.org/3.3/library/stdtypes.html?highlight=maketrans#str.maketrans) no atributo `accents_translation_table` baseando-se nas variáveis `in_table` e `out_table` também presentes no construtor (substitua o None).

# %%
print(f"{cleaner_test.remove_accents('canção')}, esperado: cancao")
print(f"{cleaner_test.remove_accents('elétrico')}, esperado: eletrico")
print(f"{cleaner_test.remove_accents('amado')}, esperado: amado")
# Out:
# cancao, esperado: cancao
# eletrico, esperado: eletrico
# amado, esperado: amado

# %% [markdown]
# Agora você irá fazer o método `preprocess_word` ele irá receber como parametro uma palavra e irá verificar se é uma palavra válida de ser indexada. Caso não seja, retornará None. Caso contrário, irá retornar a palvra preprocessada. Uma palavra válida a ser indexada é aquela que não é pontuação e não é stopword (caso `perform_stop_words_removal = True`). Para que seja feito o preprocessamento você deverá: transformar o texto para minúsculas, remover acento (se `perform_accents_removal=True`), fazer o stemming (se `perform_stemming = True`).

# %% [markdown]
# **Atividade 12 - Classe HTMLIndexer - método text_word_count: **  Você deverá implementar o método `text_word_count`, a partir de um texto. Esse método retorna um dicionário em que, para cada palavra no texto, será apresentado sua frequência. Considere que o texto já está limpo e é necessário fazer apenas o processamento das palavras.
#
# Para isso, você deverá:  dividir o texto em tokens (que, no nosso caso, são as palavras e pontuações); preprocessar cada palavra usando o `HTMLIndexer.cleaner`; e, se for uma palavra válida, contabilizá-la. Para isso, será necessário [o método word_tokenize da API NLTK](https://kite.com/python/docs/nltk.word_tokenize)

# %%
index = HashIndex()
indexador_teste = HTMLIndexer(index)
indexador_teste.text_word_count("Olá! Qual é o dado dado que precisa?")
#esperado:
#{'dad': 2, 'o': 1, 'ola': 1, 'precis': 1, 'qual': 1, 'que': 1}
# Out:
# Counter({'ola': 1, 'qual': 1, 'dad': 2, 'que': 1, 'precis': 1})

# %% [markdown]
# **Atividade 13 - método index_text: ** Implemente o método `index_text` que deverá (1) converter o HTML para texto simples usando `HTMLIndexer.cleaner`; (2) converter o texto em um dicionário de ocorrencias de palavras com sua frequencia (metodo da atividade 12); e (3) indexar cada palavra deste dicionário.

# %%
index = HashIndex()
indexador_teste = HTMLIndexer(index)
#o HTML está mal formado de propósito ;)
indexador_teste.index_text(10,"<strong>Ol&aacute;! </str> Quais são os dados que precisará?")
# ola quais sao os dados que precisara 
# ola qua<stemmed> stopword stopword dad stopword precis<stemmed>
indexador_teste.index.dic_index
# Out:
# {'ola': [(term_id:1 doc: 10 freq: 1)],
#  'qua': [(term_id:2 doc: 10 freq: 1)],
#  'sao': [(term_id:3 doc: 10 freq: 1)],
#  'os': [(term_id:4 doc: 10 freq: 1)],
#  'dad': [(term_id:5 doc: 10 freq: 1)],
#  'que': [(term_id:6 doc: 10 freq: 1)],
#  'precis': [(term_id:7 doc: 10 freq: 1)]}

# %% [markdown]
# Esperado:
# <pre>
# {'dad': [(term_id:4 doc: 10 freq: 1)],
#  'ola': [(term_id:0 doc: 10 freq: 1)],
#  'os': [(term_id:3 doc: 10 freq: 1)],
#  'precis': [(term_id:6 doc: 10 freq: 1)],
# 'qua': [(term_id:1 doc: 10 freq: 1)],
#  'que': [(term_id:5 doc: 10 freq: 1)],
#  'sao': [(term_id:2 doc: 10 freq: 1)]}
# </pre>

# %% [markdown]
# **Atividade 14: Indexação de um diretorio com subdiretorios** Você deverá implementar o método `index_text_dir` que, dado um diretorio, navega em todos os seus subdiretórios e indexa todos os arquivos HTMLs. Considere que os arquivos sejam sempre nomeados pelo seu ID. Veja o exemplo em `doc_test`. Logo após, execute o teste unitário para ver a corretude do seu indexador.

# %%
# !python3 -m index.indexer_test IndexerTest.test_indexer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/antonioaads/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/antonioaads/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/antonioaads/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.179s
#
# OK

# %% [markdown]
# Agora, para fazer a especificação do projeto, você deve baixar o dataset da Wikipédia e indexá-lo. Você deve também achar um arquivo de stopwords com mais termos aos que feito neste teste.

# %% [markdown]
# Teste utilizando a base disponível em: https://www.dropbox.com/sh/g9wkga5j6th0fvc/AABCHlyv_Tr4enXYorJV6HE6a?dl=0
# Ela não está sendo versionada no git a fim de não pesar excessivamente o repositório.
# Obs.: Caso queira testar de maneira rápida, sugiro que rode com menos dados, para obter um resultado mais imediato ("miniWikiSample")

# %%
from index.indexer import *
from index.structure import *
import sys, os

# Teste utilizando HashIndex
obj_index = HashIndex()
html_indexer = HTMLIndexer(obj_index)
html_indexer.index_text_dir("miniWikiSample")

html_indexer.index.dic_index

# Pensar uma forma de gravar isso
#with open("teste.txt", 'w') as resultado:
 #   resultado.write()
# Out:
# {'iv': [(term_id:1 doc: 101451 freq: 5),
#   (term_id:1 doc: 101823 freq: 1),
#   (term_id:1 doc: 101465 freq: 1),
#   (term_id:1 doc: 101168 freq: 6),
#   (term_id:1 doc: 101531 freq: 2),
#   (term_id:1 doc: 10198 freq: 1),
#   (term_id:1 doc: 101449 freq: 1),
#   (term_id:1 doc: 101146 freq: 1),
#   (term_id:1 doc: 101093 freq: 1),
#   (term_id:1 doc: 101150 freq: 1),
#   (term_id:1 doc: 10126 freq: 1),
#   (term_id:1 doc: 101485 freq: 1),
#   (term_id:1 doc: 101153 freq: 1),
#   (term_id:1 doc: 101549 freq: 1),
#   (term_id:1 doc: 101197 freq: 1),
#   (term_id:1 doc: 101607 freq: 1),
#   (term_id:1 doc: 1016 freq: 1),
#   (term_id:1 doc: 100765 freq: 1),
#   (term_id:1 doc: 10038 freq: 1),
#   (term_id:1 doc: 100562 freq: 3),
#   (term_id:1 doc: 100886 freq: 2),
#   (term_id:1 doc: 1005 freq: 1),
#   (term_id:1 doc: 10001 freq: 1),
#   (term_id:1 doc: 100343 freq: 1),
#   (term_id:1 doc: 100046 freq: 1),
#   (term_id:1 doc: 10015 freq: 12),
#   (term_id:1 doc: 100926 freq: 1),
#   (term_id:1 doc: 10000 freq: 1),
#   (term_id:1 doc: 100541 freq: 1),
#   (term_id:1 doc: 100470 freq: 3),
#   (term_id:1 doc: 100234 freq: 2),
#   (term_id:1 doc: 100074 freq: 3)],
#  'govern': [(term_id:2 doc: 101451 freq: 7),
#   (term_id:2 doc: 101537 freq: 5),
#   (term_id:2 doc: 101255 freq: 1),
#   (term_id:2 doc: 101929 freq: 1),
#   (term_id:2 doc: 101465 freq: 6),
#   (term_id:2 doc: 10144 freq: 4),
#   (term_id:2 doc: 101547 freq: 2),
#   (term_id:2 doc: 10140 freq: 1),
#   (term_id:2 doc: 101475 freq: 3),
#   (term_id:2 doc: 101886 freq: 1),
#   (term_id:2 doc: 101469 freq: 3),
#   (term_id:2 doc: 101480 freq: 3),
#   (term_id:2 doc: 101467 freq: 8),
#   (term_id:2 doc: 10105 freq: 3),
#   (term_id:2 doc: 10147 freq: 8),
#   (term_id:2 doc: 101124 freq: 7),
#   (term_id:2 doc: 101477 freq: 2),
#   (term_id:2 doc: 1019 freq: 5),
#   (term_id:2 doc: 1018 freq: 4),
#   (term_id:2 doc: 101294 freq: 1),
#   (term_id:2 doc: 101156 freq: 3),
#   (term_id:2 doc: 101889 freq: 1),
#   (term_id:2 doc: 101606 freq: 1),
#   (term_id:2 doc: 101752 freq: 1),
#   (term_id:2 doc: 101044 freq: 7),
#   (term_id:2 doc: 101043 freq: 8),
#   (term_id:2 doc: 101116 freq: 2),
#   (term_id:2 doc: 10148 freq: 5),
#   (term_id:2 doc: 10123 freq: 1),
#   (term_id:2 doc: 10142 freq: 2),
#   (term_id:2 doc: 101266 freq: 8),
#   (term_id:2 doc: 10183 freq: 3),
#   (term_id:2 doc: 101449 freq: 8),
#   (term_id:2 doc: 101692 freq: 1),
#   (term_id:2 doc: 101881 freq: 1),
#   (term_id:2 doc: 101118 freq: 10),
#   (term_id:2 doc: 101513 freq: 1),
#   (term_id:2 doc: 101715 freq: 1),
#   (term_id:2 doc: 101308 freq: 4),
#   (term_id:2 doc: 10175 freq: 1),
#   (term_id:2 doc: 10106 freq: 2),
#   (term_id:2 doc: 10134 freq: 1),
#   (term_id:2 doc: 101723 freq: 1),
#   (term_id:2 doc: 101481 freq: 5),
#   (term_id:2 doc: 101093 freq: 3),
#   (term_id:2 doc: 101144 freq: 1),
#   (term_id:2 doc: 101065 freq: 1),
#   (term_id:2 doc: 10146 freq: 3),
#   (term_id:2 doc: 101514 freq: 7),
#   (term_id:2 doc: 10145 freq: 1),
#   (term_id:2 doc: 101048 freq: 2),
#   (term_id:2 doc: 101831 freq: 1),
#   (term_id:2 doc: 10126 freq: 7),
#   (term_id:2 doc: 101553 freq: 1),
#   (term_id:2 doc: 101120 freq: 5),
#   (term_id:2 doc: 10107 freq: 1),
#   (term_id:2 doc: 101816 freq: 1),
#   (term_id:2 doc: 101473 freq: 2),
#   (term_id:2 doc: 10110 freq: 12),
#   (term_id:2 doc: 101051 freq: 1),
#   (term_id:2 doc: 10193 freq: 1),
#   (term_id:2 doc: 101058 freq: 3),
#   (term_id:2 doc: 10128 freq: 7),
#   (term_id:2 doc: 101163 freq: 2),
#   (term_id:2 doc: 101925 freq: 8),
#   (term_id:2 doc: 101256 freq: 4),
#   (term_id:2 doc: 101318 freq: 2),
#   (term_id:2 doc: 101466 freq: 8),
#   (term_id:2 doc: 101992 freq: 8),
#   (term_id:2 doc: 101970 freq: 3),
#   (term_id:2 doc: 101486 freq: 4),
#   (term_id:2 doc: 10196 freq: 3),
#   (term_id:2 doc: 101468 freq: 5),
#   (term_id:2 doc: 101936 freq: 1),
#   (term_id:2 doc: 10192 freq: 1),
#   (term_id:2 doc: 101744 freq: 1),
#   (term_id:2 doc: 10149 freq: 6),
#   (term_id:2 doc: 101585 freq: 1),
#   (term_id:2 doc: 101922 freq: 1),
#   (term_id:2 doc: 101082 freq: 1),
#   (term_id:2 doc: 10057 freq: 1),
#   (term_id:2 doc: 100701 freq: 1),
#   (term_id:2 doc: 100995 freq: 7),
#   (term_id:2 doc: 100964 freq: 1),
#   (term_id:2 doc: 100946 freq: 2),
#   (term_id:2 doc: 100793 freq: 2),
#   (term_id:2 doc: 100886 freq: 1),
#   (term_id:2 doc: 100120 freq: 1),
#   (term_id:2 doc: 100709 freq: 4),
#   (term_id:2 doc: 100879 freq: 4),
#   (term_id:2 doc: 100638 freq: 4),
#   (term_id:2 doc: 100357 freq: 1),
#   (term_id:2 doc: 100777 freq: 4),
#   (term_id:2 doc: 1005 freq: 32),
#   (term_id:2 doc: 100711 freq: 5),
#   (term_id:2 doc: 100652 freq: 1),
#   (term_id:2 doc: 1007 freq: 1),
#   (term_id:2 doc: 100719 freq: 1),
#   (term_id:2 doc: 100136 freq: 2),
#   (term_id:2 doc: 100667 freq: 1),
#   (term_id:2 doc: 100686 freq: 1),
#   (term_id:2 doc: 100642 freq: 1),
#   (term_id:2 doc: 100661 freq: 1),
#   (term_id:2 doc: 100305 freq: 1),
#   (term_id:2 doc: 100448 freq: 6),
#   (term_id:2 doc: 100710 freq: 3),
#   (term_id:2 doc: 100185 freq: 2),
#   (term_id:2 doc: 100344 freq: 8),
#   (term_id:2 doc: 100657 freq: 1),
#   (term_id:2 doc: 100157 freq: 19),
#   (term_id:2 doc: 100480 freq: 6),
#   (term_id:2 doc: 100792 freq: 3),
#   (term_id:2 doc: 100824 freq: 3),
#   (term_id:2 doc: 100658 freq: 1),
#   (term_id:2 doc: 100854 freq: 8),
#   (term_id:2 doc: 100659 freq: 1),
#   (term_id:2 doc: 100668 freq: 1),
#   (term_id:2 doc: 100787 freq: 6),
#   (term_id:2 doc: 100644 freq: 3),
#   (term_id:2 doc: 100706 freq: 1),
#   (term_id:2 doc: 100837 freq: 1),
#   (term_id:2 doc: 1008 freq: 12),
#   (term_id:2 doc: 100633 freq: 4),
#   (term_id:2 doc: 10082 freq: 1),
#   (term_id:2 doc: 100785 freq: 2),
#   (term_id:2 doc: 100815 freq: 1),
#   (term_id:2 doc: 100698 freq: 1),
#   (term_id:2 doc: 100662 freq: 1),
#   (term_id:2 doc: 100592 freq: 1),
#   (term_id:2 doc: 10015 freq: 10),
#   (term_id:2 doc: 100705 freq: 2),
#   (term_id:2 doc: 100926 freq: 1),
#   (term_id:2 doc: 100980 freq: 3),
#   (term_id:2 doc: 10049 freq: 3),
#   (term_id:2 doc: 10037 freq: 3),
#   (term_id:2 doc: 100704 freq: 2),
#   (term_id:2 doc: 100314 freq: 1),
#   (term_id:2 doc: 100038 freq: 4),
#   (term_id:2 doc: 100708 freq: 8),
#   (term_id:2 doc: 100809 freq: 12),
#   (term_id:2 doc: 100795 freq: 1),
#   (term_id:2 doc: 100589 freq: 9),
#   (term_id:2 doc: 100663 freq: 1),
#   (term_id:2 doc: 100028 freq: 2),
#   (term_id:2 doc: 100977 freq: 2),
#   (term_id:2 doc: 100575 freq: 1),
#   (term_id:2 doc: 100105 freq: 3),
#   (term_id:2 doc: 100074 freq: 4),
#   (term_id:2 doc: 10008 freq: 1),
#   (term_id:2 doc: 100665 freq: 1),
#   (term_id:2 doc: 100331 freq: 2),
#   (term_id:2 doc: 100245 freq: 3),
#   (term_id:2 doc: 100660 freq: 1)],
#  'constitucional': [(term_id:3 doc: 101451 freq: 5),
#   (term_id:3 doc: 101537 freq: 1),
#   (term_id:3 doc: 101465 freq: 3),
#   (term_id:3 doc: 101547 freq: 1),
#   (term_id:3 doc: 101475 freq: 2),
#   (term_id:3 doc: 101469 freq: 2),
#   (term_id:3 doc: 101480 freq: 3),
#   (term_id:3 doc: 101467 freq: 2),
#   (term_id:3 doc: 10147 freq: 1),
#   (term_id:3 doc: 101124 freq: 4),
#   (term_id:3 doc: 101477 freq: 2),
#   (term_id:3 doc: 1019 freq: 1),
#   (term_id:3 doc: 101116 freq: 1),
#   (term_id:3 doc: 101266 freq: 1),
#   (term_id:3 doc: 101449 freq: 6),
#   (term_id:3 doc: 101481 freq: 4),
#   (term_id:3 doc: 101120 freq: 3),
#   (term_id:3 doc: 101473 freq: 2),
#   (term_id:3 doc: 101485 freq: 2),
#   (term_id:3 doc: 101466 freq: 2),
#   (term_id:3 doc: 10196 freq: 1),
#   (term_id:3 doc: 101468 freq: 2),
#   (term_id:3 doc: 101141 freq: 1),
#   (term_id:3 doc: 100701 freq: 1),
#   (term_id:3 doc: 100709 freq: 1),
#   (term_id:3 doc: 100711 freq: 3),
#   (term_id:3 doc: 100735 freq: 26),
#   (term_id:3 doc: 100448 freq: 2),
#   (term_id:3 doc: 100710 freq: 2),
#   (term_id:3 doc: 100515 freq: 1),
#   (term_id:3 doc: 100157 freq: 1),
#   (term_id:3 doc: 100854 freq: 1),
#   (term_id:3 doc: 100706 freq: 1),
#   (term_id:3 doc: 100741 freq: 4),
#   (term_id:3 doc: 100815 freq: 1),
#   (term_id:3 doc: 100705 freq: 1),
#   (term_id:3 doc: 100767 freq: 1),
#   (term_id:3 doc: 100704 freq: 2),
#   (term_id:3 doc: 100708 freq: 4),
#   (term_id:3 doc: 100809 freq: 2),
#   (term_id:3 doc: 100589 freq: 1)],
#  'portugal': [(term_id:4 doc: 101451 freq: 3),
#   (term_id:4 doc: 101537 freq: 7),
#   (term_id:4 doc: 101255 freq: 7),
#   (term_id:4 doc: 10153 freq: 1),
#   (term_id:4 doc: 101170 freq: 5),
#   (term_id:4 doc: 101177 freq: 6),
#   (term_id:4 doc: 101465 freq: 1),
#   (term_id:4 doc: 101168 freq: 5),
#   (term_id:4 doc: 101529 freq: 1),
#   (term_id:4 doc: 101547 freq: 10),
#   (term_id:4 doc: 101475 freq: 1),
#   (term_id:4 doc: 101531 freq: 6),
#   (term_id:4 doc: 101434 freq: 1),
#   (term_id:4 doc: 101071 freq: 1),
#   (term_id:4 doc: 101660 freq: 1),
#   (term_id:4 doc: 101469 freq: 1),
#   (term_id:4 doc: 101480 freq: 1),
#   (term_id:4 doc: 101467 freq: 1),
#   (term_id:4 doc: 101706 freq: 1),
#   (term_id:4 doc: 10105 freq: 1),
#   (term_id:4 doc: 101124 freq: 2),
#   (term_id:4 doc: 101726 freq: 2),
#   (term_id:4 doc: 101477 freq: 1),
#   (term_id:4 doc: 101658 freq: 2),
#   (term_id:4 doc: 10104 freq: 8),
#   (term_id:4 doc: 1019 freq: 2),
#   (term_id:4 doc: 101707 freq: 2),
#   (term_id:4 doc: 101605 freq: 1),
#   (term_id:4 doc: 10198 freq: 1),
#   (term_id:4 doc: 101663 freq: 2),
#   (term_id:4 doc: 101161 freq: 15),
#   (term_id:4 doc: 101266 freq: 5),
#   (term_id:4 doc: 101674 freq: 3),
#   (term_id:4 doc: 101343 freq: 1),
#   (term_id:4 doc: 101449 freq: 3),
#   (term_id:4 doc: 101692 freq: 1),
#   (term_id:4 doc: 101070 freq: 1),
#   (term_id:4 doc: 101742 freq: 1),
#   (term_id:4 doc: 101720 freq: 3),
#   (term_id:4 doc: 101208 freq: 1),
#   (term_id:4 doc: 101818 freq: 1),
#   (term_id:4 doc: 101841 freq: 3),
#   (term_id:4 doc: 10141 freq: 1),
#   (term_id:4 doc: 101481 freq: 1),
#   (term_id:4 doc: 101093 freq: 8),
#   (term_id:4 doc: 10146 freq: 1),
#   (term_id:4 doc: 101514 freq: 1),
#   (term_id:4 doc: 101879 freq: 4),
#   (term_id:4 doc: 101676 freq: 2),
#   (term_id:4 doc: 101048 freq: 7),
#   (term_id:4 doc: 101120 freq: 1),
#   (term_id:4 doc: 101473 freq: 1),
#   (term_id:4 doc: 10150 freq: 4),
#   (term_id:4 doc: 101696 freq: 3),
#   (term_id:4 doc: 101670 freq: 3),
#   (term_id:4 doc: 101981 freq: 3),
#   (term_id:4 doc: 101679 freq: 1),
#   (term_id:4 doc: 101079 freq: 2),
#   (term_id:4 doc: 101256 freq: 2),
#   (term_id:4 doc: 101505 freq: 2),
#   (term_id:4 doc: 101691 freq: 1),
#   (term_id:4 doc: 101485 freq: 4),
#   (term_id:4 doc: 101466 freq: 1),
#   (term_id:4 doc: 101992 freq: 4),
#   (term_id:4 doc: 101652 freq: 7),
#   (term_id:4 doc: 101080 freq: 6),
#   (term_id:4 doc: 101153 freq: 18),
#   (term_id:4 doc: 101708 freq: 3),
#   (term_id:4 doc: 10196 freq: 5),
#   (term_id:4 doc: 101468 freq: 1),
#   (term_id:4 doc: 101197 freq: 12),
#   (term_id:4 doc: 10192 freq: 1),
#   (term_id:4 doc: 10149 freq: 1),
#   (term_id:4 doc: 101922 freq: 20),
#   (term_id:4 doc: 101141 freq: 16),
#   (term_id:4 doc: 101621 freq: 2),
#   (term_id:4 doc: 101082 freq: 1),
#   (term_id:4 doc: 10058 freq: 2),
#   (term_id:4 doc: 100701 freq: 9),
#   (term_id:4 doc: 10033 freq: 1),
#   (term_id:4 doc: 100045 freq: 8),
#   (term_id:4 doc: 100915 freq: 1),
#   (term_id:4 doc: 100886 freq: 2),
#   (term_id:4 doc: 100709 freq: 4),
#   (term_id:4 doc: 100879 freq: 1),
#   (term_id:4 doc: 100770 freq: 1),
#   (term_id:4 doc: 10066 freq: 4),
#   (term_id:4 doc: 100221 freq: 1),
#   (term_id:4 doc: 100862 freq: 2),
#   (term_id:4 doc: 100357 freq: 1),
#   (term_id:4 doc: 100776 freq: 1),
#   (term_id:4 doc: 100797 freq: 1),
#   (term_id:4 doc: 10018 freq: 8),
#   (term_id:4 doc: 100711 freq: 4),
#   (term_id:4 doc: 100905 freq: 1),
#   (term_id:4 doc: 100135 freq: 3),
#   (term_id:4 doc: 100938 freq: 2),
#   (term_id:4 doc: 10024 freq: 1),
#   (term_id:4 doc: 100936 freq: 5),
#   (term_id:4 doc: 100735 freq: 3),
#   (term_id:4 doc: 100448 freq: 2),
#   (term_id:4 doc: 100308 freq: 1),
#   (term_id:4 doc: 100710 freq: 7),
#   (term_id:4 doc: 100185 freq: 3),
#   (term_id:4 doc: 10025 freq: 1),
#   (term_id:4 doc: 100920 freq: 3),
#   (term_id:4 doc: 100480 freq: 1),
#   (term_id:4 doc: 10073 freq: 1),
#   (term_id:4 doc: 100854 freq: 3),
#   (term_id:4 doc: 100769 freq: 2),
#   (term_id:4 doc: 10053 freq: 2),
#   (term_id:4 doc: 100345 freq: 1),
#   (term_id:4 doc: 100483 freq: 2),
#   (term_id:4 doc: 10023 freq: 1),
#   (term_id:4 doc: 100775 freq: 1),
#   (term_id:4 doc: 100911 freq: 1),
#   (term_id:4 doc: 100787 freq: 1),
#   (term_id:4 doc: 100438 freq: 1),
#   (term_id:4 doc: 100519 freq: 2),
#   (term_id:4 doc: 100706 freq: 4),
#   (term_id:4 doc: 100471 freq: 2),
#   (term_id:4 doc: 100741 freq: 2),
#   (term_id:4 doc: 1008 freq: 1),
#   (term_id:4 doc: 100785 freq: 1),
#   (term_id:4 doc: 100815 freq: 1),
#   (term_id:4 doc: 100998 freq: 1),
#   (term_id:4 doc: 100705 freq: 5),
#   (term_id:4 doc: 100767 freq: 5),
#   (term_id:4 doc: 100926 freq: 6),
#   (term_id:4 doc: 100980 freq: 1),
#   (term_id:4 doc: 100962 freq: 1),
#   (term_id:4 doc: 100704 freq: 5),
#   (term_id:4 doc: 10064 freq: 4),
#   (term_id:4 doc: 100708 freq: 4),
#   (term_id:4 doc: 100809 freq: 6),
#   (term_id:4 doc: 10087 freq: 1),
#   (term_id:4 doc: 100008 freq: 1),
#   (term_id:4 doc: 10000 freq: 1),
#   (term_id:4 doc: 100085 freq: 1),
#   (term_id:4 doc: 100945 freq: 2),
#   (term_id:4 doc: 100234 freq: 1),
#   (term_id:4 doc: 10086 freq: 1),
#   (term_id:4 doc: 100439 freq: 1),
#   (term_id:4 doc: 100245 freq: 7),
#   (term_id:4 doc: 100445 freq: 1),
#   (term_id:4 doc: 100922 freq: 1)],
#  'o': [(term_id:5 doc: 101451 freq: 2),
#   (term_id:5 doc: 101414 freq: 2),
#   (term_id:5 doc: 101326 freq: 1),
#   (term_id:5 doc: 101534 freq: 2),
#   (term_id:5 doc: 101537 freq: 1),
#   (term_id:5 doc: 101539 freq: 2),
#   (term_id:5 doc: 101255 freq: 8),
#   (term_id:5 doc: 101909 freq: 3),
#   (term_id:5 doc: 101939 freq: 2),
#   (term_id:5 doc: 10121 freq: 29),
#   (term_id:5 doc: 101929 freq: 1),
#   (term_id:5 doc: 101542 freq: 1),
#   (term_id:5 doc: 101247 freq: 1),
#   (term_id:5 doc: 101671 freq: 3),
#   (term_id:5 doc: 101785 freq: 89),
#   (term_id:5 doc: 101536 freq: 1),
#   (term_id:5 doc: 10153 freq: 4),
#   (term_id:5 doc: 101320 freq: 1),
#   (term_id:5 doc: 101823 freq: 2),
#   (term_id:5 doc: 10172 freq: 1),
#   (term_id:5 doc: 101056 freq: 2),
#   (term_id:5 doc: 101721 freq: 1),
#   (term_id:5 doc: 101177 freq: 3),
#   (term_id:5 doc: 101763 freq: 16),
#   (term_id:5 doc: 101819 freq: 3),
#   (term_id:5 doc: 101063 freq: 5),
#   (term_id:5 doc: 101753 freq: 2),
#   (term_id:5 doc: 10158 freq: 3),
#   (term_id:5 doc: 101465 freq: 1),
#   (term_id:5 doc: 101168 freq: 1),
#   (term_id:5 doc: 10144 freq: 5),
#   (term_id:5 doc: 101926 freq: 1),
#   (term_id:5 doc: 101275 freq: 1),
#   (term_id:5 doc: 101930 freq: 1),
#   (term_id:5 doc: 101695 freq: 4),
#   (term_id:5 doc: 10140 freq: 2),
#   (term_id:5 doc: 101475 freq: 1),
#   (term_id:5 doc: 101074 freq: 5),
#   (term_id:5 doc: 101082 freq: 1),
#   (term_id:5 doc: 101747 freq: 1),
#   (term_id:5 doc: 101661 freq: 1),
#   (term_id:5 doc: 100895 freq: 3),
#   (term_id:5 doc: 10058 freq: 1),
#   (term_id:5 doc: 100581 freq: 2),
#   (term_id:5 doc: 100162 freq: 2),
#   (term_id:5 doc: 10020 freq: 4),
#   (term_id:5 doc: 100213 freq: 1),
#   (term_id:5 doc: 100275 freq: 1),
#   (term_id:5 doc: 100588 freq: 1),
#   (term_id:5 doc: 100564 freq: 4),
#   (term_id:5 doc: 100765 freq: 1),
#   (term_id:5 doc: 100454 freq: 3),
#   (term_id:5 doc: 100212 freq: 3),
#   (term_id:5 doc: 100701 freq: 2),
#   (term_id:5 doc: 100021 freq: 15),
#   (term_id:5 doc: 100172 freq: 2),
#   (term_id:5 doc: 100995 freq: 4),
#   (term_id:5 doc: 100734 freq: 1),
#   (term_id:5 doc: 100539 freq: 2),
#   (term_id:5 doc: 100634 freq: 2),
#   (term_id:5 doc: 100306 freq: 7),
#   (term_id:5 doc: 100946 freq: 1),
#   (term_id:5 doc: 10038 freq: 51),
#   (term_id:5 doc: 100838 freq: 1),
#   (term_id:5 doc: 100562 freq: 23),
#   (term_id:5 doc: 100915 freq: 1),
#   (term_id:5 doc: 100793 freq: 4),
#   (term_id:5 doc: 100391 freq: 10),
#   (term_id:5 doc: 100672 freq: 3),
#   (term_id:5 doc: 100900 freq: 1),
#   (term_id:5 doc: 100120 freq: 3),
#   (term_id:5 doc: 100013 freq: 1),
#   (term_id:5 doc: 100274 freq: 5),
#   (term_id:5 doc: 100637 freq: 1),
#   (term_id:5 doc: 100186 freq: 2),
#   (term_id:5 doc: 100879 freq: 6),
#   (term_id:5 doc: 100907 freq: 1),
#   (term_id:5 doc: 100267 freq: 1),
#   (term_id:5 doc: 100744 freq: 1),
#   (term_id:5 doc: 100638 freq: 4),
#   (term_id:5 doc: 100221 freq: 4),
#   (term_id:5 doc: 100862 freq: 2),
#   (term_id:5 doc: 100393 freq: 2),
#   (term_id:5 doc: 100357 freq: 11),
#   (term_id:5 doc: 100892 freq: 2),
#   (term_id:5 doc: 100777 freq: 4),
#   (term_id:5 doc: 100677 freq: 4),
#   (term_id:5 doc: 100776 freq: 2),
#   (term_id:5 doc: 1005 freq: 35),
#   (term_id:5 doc: 100797 freq: 2),
#   (term_id:5 doc: 100406 freq: 2),
#   (term_id:5 doc: 10018 freq: 16),
#   (term_id:5 doc: 100679 freq: 4),
#   (term_id:5 doc: 100711 freq: 1),
#   (term_id:5 doc: 100975 freq: 1),
#   (term_id:5 doc: 1007 freq: 1),
#   (term_id:5 doc: 100719 freq: 1),
#   (term_id:5 doc: 100136 freq: 6),
#   (term_id:5 doc: 100030 freq: 1),
#   (term_id:5 doc: 100350 freq: 6),
#   (term_id:5 doc: 100075 freq: 3),
#   (term_id:5 doc: 100889 freq: 2),
#   (term_id:5 doc: 100686 freq: 1),
#   (term_id:5 doc: 100630 freq: 2),
#   (term_id:5 doc: 100631 freq: 3),
#   (term_id:5 doc: 100135 freq: 9),
#   (term_id:5 doc: 100548 freq: 3),
#   (term_id:5 doc: 100782 freq: 2),
#   (term_id:5 doc: 100629 freq: 4),
#   (term_id:5 doc: 100938 freq: 1),
#   (term_id:5 doc: 100884 freq: 8),
#   (term_id:5 doc: 100579 freq: 4),
#   (term_id:5 doc: 100682 freq: 1),
#   (term_id:5 doc: 100268 freq: 3),
#   (term_id:5 doc: 100925 freq: 2),
#   (term_id:5 doc: 100511 freq: 1),
#   (term_id:5 doc: 100642 freq: 1),
#   (term_id:5 doc: 100006 freq: 4),
#   (term_id:5 doc: 10061 freq: 1),
#   (term_id:5 doc: 100453 freq: 2),
#   (term_id:5 doc: 10042 freq: 5),
#   (term_id:5 doc: 100049 freq: 1),
#   (term_id:5 doc: 100305 freq: 3),
#   (term_id:5 doc: 10024 freq: 3),
#   (term_id:5 doc: 100901 freq: 2),
#   (term_id:5 doc: 10071 freq: 1),
#   (term_id:5 doc: 100755 freq: 10),
#   (term_id:5 doc: 100936 freq: 8),
#   (term_id:5 doc: 100735 freq: 10),
#   (term_id:5 doc: 100448 freq: 2),
#   (term_id:5 doc: 100229 freq: 1),
#   (term_id:5 doc: 100986 freq: 5),
#   (term_id:5 doc: 100788 freq: 3),
#   (term_id:5 doc: 100593 freq: 1),
#   (term_id:5 doc: 100724 freq: 8),
#   (term_id:5 doc: 100262 freq: 1),
#   (term_id:5 doc: 100985 freq: 1),
#   (term_id:5 doc: 100902 freq: 7),
#   (term_id:5 doc: 100308 freq: 4),
#   (term_id:5 doc: 100710 freq: 6),
#   (term_id:5 doc: 100185 freq: 13),
#   (term_id:5 doc: 100618 freq: 2),
#   (term_id:5 doc: 100344 freq: 4),
#   (term_id:5 doc: 100733 freq: 1),
#   (term_id:5 doc: 100515 freq: 11),
#   (term_id:5 doc: 100831 freq: 2),
#   (term_id:5 doc: 100687 freq: 2),
#   (term_id:5 doc: 100920 freq: 8),
#   (term_id:5 doc: 100157 freq: 27),
#   (term_id:5 doc: 100480 freq: 23),
#   (term_id:5 doc: 100552 freq: 23),
#   (term_id:5 doc: 10007 freq: 4),
#   (term_id:5 doc: 100893 freq: 1),
#   (term_id:5 doc: 100824 freq: 12),
#   (term_id:5 doc: 100658 freq: 1),
#   (term_id:5 doc: 100854 freq: 5),
#   (term_id:5 doc: 100821 freq: 3),
#   (term_id:5 doc: 100659 freq: 5),
#   (term_id:5 doc: 100668 freq: 5),
#   (term_id:5 doc: 100627 freq: 1),
#   (term_id:5 doc: 100873 freq: 5),
#   (term_id:5 doc: 100601 freq: 1),
#   (term_id:5 doc: 100681 freq: 1),
#   (term_id:5 doc: 100011 freq: 2),
#   (term_id:5 doc: 100337 freq: 1),
#   (term_id:5 doc: 100046 freq: 41),
#   (term_id:5 doc: 100336 freq: 2),
#   (term_id:5 doc: 100345 freq: 2),
#   (term_id:5 doc: 100215 freq: 1),
#   (term_id:5 doc: 100395 freq: 1),
#   (term_id:5 doc: 100599 freq: 2),
#   (term_id:5 doc: 10023 freq: 14),
#   (term_id:5 doc: 100184 freq: 10),
#   (term_id:5 doc: 100382 freq: 1),
#   (term_id:5 doc: 100106 freq: 2),
#   (term_id:5 doc: 100911 freq: 7),
#   (term_id:5 doc: 100787 freq: 3),
#   (term_id:5 doc: 100426 freq: 2),
#   (term_id:5 doc: 100369 freq: 1),
#   (term_id:5 doc: 100671 freq: 1),
#   (term_id:5 doc: 10068 freq: 1),
#   (term_id:5 doc: 100363 freq: 11),
#   (term_id:5 doc: 100571 freq: 1),
#   (term_id:5 doc: 100128 freq: 2),
#   (term_id:5 doc: 100078 freq: 2),
#   (term_id:5 doc: 100487 freq: 1),
#   (term_id:5 doc: 10070 freq: 2),
#   (term_id:5 doc: 100519 freq: 2),
#   (term_id:5 doc: 10079 freq: 1),
#   (term_id:5 doc: 100628 freq: 1),
#   (term_id:5 doc: 100683 freq: 6),
#   (term_id:5 doc: 100327 freq: 2),
#   (term_id:5 doc: 100358 freq: 4),
#   (term_id:5 doc: 100837 freq: 2),
#   (term_id:5 doc: 100333 freq: 1),
#   (term_id:5 doc: 100373 freq: 1),
#   (term_id:5 doc: 100042 freq: 10),
#   (term_id:5 doc: 10099 freq: 2),
#   (term_id:5 doc: 10050 freq: 9),
#   (term_id:5 doc: 100384 freq: 1),
#   (term_id:5 doc: 100729 freq: 2),
#   (term_id:5 doc: 100160 freq: 4),
#   (term_id:5 doc: 100743 freq: 16),
#   (term_id:5 doc: 100353 freq: 1),
#   (term_id:5 doc: 100147 freq: 2),
#   (term_id:5 doc: 1008 freq: 34),
#   (term_id:5 doc: 10002 freq: 1),
#   (term_id:5 doc: 100633 freq: 2),
#   (term_id:5 doc: 100702 freq: 4),
#   (term_id:5 doc: 100002 freq: 18),
#   (term_id:5 doc: 10065 freq: 1),
#   (term_id:5 doc: 100151 freq: 2),
#   (term_id:5 doc: 100785 freq: 10),
#   (term_id:5 doc: 100368 freq: 4),
#   (term_id:5 doc: 100836 freq: 1),
#   (term_id:5 doc: 100998 freq: 19),
#   (term_id:5 doc: 100355 freq: 1),
#   (term_id:5 doc: 100698 freq: 7),
#   (term_id:5 doc: 100163 freq: 8),
#   (term_id:5 doc: 100026 freq: 10),
#   (term_id:5 doc: 100592 freq: 3),
#   (term_id:5 doc: 100799 freq: 1),
#   (term_id:5 doc: 10015 freq: 17),
#   (term_id:5 doc: 100705 freq: 1),
#   (term_id:5 doc: 100767 freq: 4),
#   (term_id:5 doc: 100926 freq: 2),
#   (term_id:5 doc: 100064 freq: 1),
#   (term_id:5 doc: 100768 freq: 36),
#   (term_id:5 doc: 100980 freq: 8),
#   (term_id:5 doc: 10049 freq: 1),
#   (term_id:5 doc: 100685 freq: 1),
#   (term_id:5 doc: 100740 freq: 5),
#   (term_id:5 doc: 10037 freq: 13),
#   (term_id:5 doc: 100962 freq: 2),
#   (term_id:5 doc: 100380 freq: 1),
#   (term_id:5 doc: 10036 freq: 6),
#   (term_id:5 doc: 100354 freq: 2),
#   (term_id:5 doc: 100056 freq: 2),
#   (term_id:5 doc: 1006 freq: 1),
#   (term_id:5 doc: 100038 freq: 1),
#   (term_id:5 doc: 100205 freq: 5),
#   (term_id:5 doc: 100386 freq: 1),
#   (term_id:5 doc: 100179 freq: 10),
#   (term_id:5 doc: 100809 freq: 16),
#   (term_id:5 doc: 1001 freq: 1),
#   (term_id:5 doc: 100387 freq: 1),
#   (term_id:5 doc: 10087 freq: 1),
#   (term_id:5 doc: 100795 freq: 4),
#   (term_id:5 doc: 100425 freq: 1),
#   (term_id:5 doc: 100714 freq: 1),
#   (term_id:5 doc: 10000 freq: 4),
#   (term_id:5 doc: 100589 freq: 4),
#   (term_id:5 doc: 100663 freq: 1),
#   (term_id:5 doc: 100329 freq: 3),
#   (term_id:5 doc: 100052 freq: 14),
#   (term_id:5 doc: 10031 freq: 3),
#   (term_id:5 doc: 100541 freq: 9),
#   (term_id:5 doc: 100009 freq: 2),
#   (term_id:5 doc: 100811 freq: 3),
#   (term_id:5 doc: 100673 freq: 2),
#   (term_id:5 doc: 100470 freq: 5),
#   (term_id:5 doc: 100028 freq: 3),
#   (term_id:5 doc: 100385 freq: 1),
#   (term_id:5 doc: 100977 freq: 5),
#   (term_id:5 doc: 100575 freq: 1),
#   (term_id:5 doc: 100906 freq: 1),
#   (term_id:5 doc: 100779 freq: 4),
#   (term_id:5 doc: 100945 freq: 2),
#   (term_id:5 doc: 100607 freq: 7),
#   (term_id:5 doc: 100217 freq: 3),
#   (term_id:5 doc: 100105 freq: 6),
#   (term_id:5 doc: 100614 freq: 16),
#   (term_id:5 doc: 100957 freq: 2),
#   (term_id:5 doc: 100234 freq: 9),
#   (term_id:5 doc: 100636 freq: 1),
#   (term_id:5 doc: 100970 freq: 3),
#   (term_id:5 doc: 100763 freq: 2),
#   (term_id:5 doc: 100074 freq: 2),
#   (term_id:5 doc: 10008 freq: 13),
#   (term_id:5 doc: 100439 freq: 1),
#   (term_id:5 doc: 100331 freq: 5),
#   (term_id:5 doc: 100245 freq: 7),
#   (term_id:5 doc: 100720 freq: 8),
#   (term_id:5 doc: 100018 freq: 1),
#   (term_id:5 doc: 1002 freq: 10),
#   (term_id:5 doc: 100660 freq: 1)],
#  'tom': [(term_id:6 doc: 101451 freq: 3),
#   (term_id:6 doc: 101775 freq: 1),
#   (term_id:6 doc: 101535 freq: 1),
#   (term_id:6 doc: 101255 freq: 1),
#   (term_id:6 doc: 10121 freq: 1),
#   (term_id:6 doc: 101785 freq: 1),
#   (term_id:6 doc: 101729 freq: 1),
#   (term_id:6 doc: 101465 freq: 3),
#   (term_id:6 doc: 10144 freq: 3),
#   (term_id:6 doc: 101475 freq: 1),
#   (term_id:6 doc: 101433 freq: 1),
#   (term_id:6 doc: 101469 freq: 2),
#   (term_id:6 doc: 101480 freq: 1),
#   (term_id:6 doc: 101467 freq: 4),
#   (term_id:6 doc: 101512 freq: 2),
#   (term_id:6 doc: 10105 freq: 5),
#   (term_id:6 doc: 101541 freq: 4),
#   (term_id:6 doc: 100641 freq: 1),
#   (term_id:6 doc: 100770 freq: 1),
#   (term_id:6 doc: 1005 freq: 3),
#   (term_id:6 doc: 100350 freq: 1),
#   (term_id:6 doc: 100511 freq: 1),
#   (term_id:6 doc: 100661 freq: 1),
#   (term_id:6 doc: 100936 freq: 1),
#   (term_id:6 doc: 100710 freq: 1),
#   (term_id:6 doc: 100185 freq: 1),
#   (term_id:6 doc: 100344 freq: 1),
#   (term_id:6 doc: 100157 freq: 9),
#   (term_id:6 doc: 100480 freq: 6),
#   (term_id:6 doc: 100824 freq: 2),
#   (term_id:6 doc: 100854 freq: 3),
#   (term_id:6 doc: 100668 freq: 1),
#   (term_id:6 doc: 100601 freq: 1),
#   (term_id:6 doc: 100046 freq: 1),
#   (term_id:6 doc: 100042 freq: 6),
#   (term_id:6 doc: 10050 freq: 1),
#   (term_id:6 doc: 1008 freq: 1),
#   (term_id:6 doc: 100785 freq: 2),
#   (term_id:6 doc: 100998 freq: 1),
#   (term_id:6 doc: 100592 freq: 1),
#   (term_id:6 doc: 10015 freq: 1),
#   (term_id:6 doc: 100767 freq: 1),
#   (term_id:6 doc: 100768 freq: 2),
#   (term_id:6 doc: 100685 freq: 1),
#   (term_id:6 doc: 10037 freq: 5),
#   (term_id:6 doc: 100179 freq: 1),
#   (term_id:6 doc: 10000 freq: 2),
#   (term_id:6 doc: 100052 freq: 3),
#   (term_id:6 doc: 100541 freq: 1),
#   (term_id:6 doc: 100470 freq: 1),
#   (term_id:6 doc: 100977 freq: 1),
#   (term_id:6 doc: 100575 freq: 3),
#   (term_id:6 doc: 100607 freq: 1),
#   (term_id:6 doc: 100217 freq: 1),
#   (term_id:6 doc: 100105 freq: 1),
#   (term_id:6 doc: 100234 freq: 2),
#   (term_id:6 doc: 100730 freq: 1),
#   (term_id:6 doc: 100074 freq: 2),
#   (term_id:6 doc: 100245 freq: 1),
#   (term_id:6 doc: 100720 freq: 5),
#   (term_id:6 doc: 1002 freq: 1)],
#  'poss': [(term_id:7 doc: 101451 freq: 2),
#   (term_id:7 doc: 101465 freq: 2),
#   (term_id:7 doc: 10144 freq: 1),
#   (term_id:7 doc: 101475 freq: 1),
#   (term_id:7 doc: 101771 freq: 1),
#   (term_id:7 doc: 101469 freq: 1),
#   (term_id:7 doc: 101480 freq: 1),
#   (term_id:7 doc: 101467 freq: 3),
#   (term_id:7 doc: 101541 freq: 1),
#   (term_id:7 doc: 101882 freq: 1),
#   (term_id:7 doc: 10147 freq: 2),
#   (term_id:7 doc: 101477 freq: 1),
#   (term_id:7 doc: 101817 freq: 1),
#   (term_id:7 doc: 101954 freq: 1),
#   (term_id:7 doc: 101624 freq: 1),
#   (term_id:7 doc: 101248 freq: 1),
#   (term_id:7 doc: 101449 freq: 2),
#   (term_id:7 doc: 10106 freq: 3),
#   (term_id:7 doc: 101411 freq: 3),
#   (term_id:7 doc: 10141 freq: 1),
#   (term_id:7 doc: 101481 freq: 1),
#   (term_id:7 doc: 101120 freq: 1),
#   (term_id:7 doc: 10107 freq: 1),
#   (term_id:7 doc: 101816 freq: 1),
#   (term_id:7 doc: 101473 freq: 1),
#   (term_id:7 doc: 10110 freq: 1),
#   (term_id:7 doc: 10193 freq: 1),
#   (term_id:7 doc: 101318 freq: 1),
#   (term_id:7 doc: 101466 freq: 2),
#   (term_id:7 doc: 101486 freq: 2),
#   (term_id:7 doc: 101708 freq: 1),
#   (term_id:7 doc: 10196 freq: 1),
#   (term_id:7 doc: 101468 freq: 2),
#   (term_id:7 doc: 101639 freq: 1),
#   (term_id:7 doc: 101922 freq: 1),
#   (term_id:7 doc: 10038 freq: 6),
#   (term_id:7 doc: 100638 freq: 1),
#   (term_id:7 doc: 100221 freq: 1),
#   (term_id:7 doc: 100862 freq: 1),
#   (term_id:7 doc: 100393 freq: 1),
#   (term_id:7 doc: 1005 freq: 1),
#   (term_id:7 doc: 100782 freq: 2),
#   (term_id:7 doc: 100305 freq: 2),
#   (term_id:7 doc: 100480 freq: 3),
#   (term_id:7 doc: 100854 freq: 1),
#   (term_id:7 doc: 100668 freq: 1),
#   (term_id:7 doc: 100363 freq: 1),
#   (term_id:7 doc: 1008 freq: 2),
#   (term_id:7 doc: 10002 freq: 1),
#   (term_id:7 doc: 100151 freq: 1),
#   (term_id:7 doc: 100026 freq: 1),
#   (term_id:7 doc: 100768 freq: 5),
#   (term_id:7 doc: 10037 freq: 3),
#   (term_id:7 doc: 100589 freq: 1),
#   (term_id:7 doc: 100470 freq: 3),
#   (term_id:7 doc: 100074 freq: 1)],
#  '22': [(term_id:8 doc: 101451 freq: 21),
#   (term_id:8 doc: 101785 freq: 3),
#   (term_id:8 doc: 101697 freq: 3),
#   (term_id:8 doc: 101960 freq: 1),
#   (term_id:8 doc: 101750 freq: 2),
#   (term_id:8 doc: 101763 freq: 1),
#   (term_id:8 doc: 101753 freq: 1),
#   (term_id:8 doc: 101168 freq: 1),
#   (term_id:8 doc: 101547 freq: 1),
#   (term_id:8 doc: 101593 freq: 1),
#   (term_id:8 doc: 101930 freq: 1),
#   (term_id:8 doc: 101695 freq: 3),
#   (term_id:8 doc: 101710 freq: 1),
#   (term_id:8 doc: 101771 freq: 1),
#   (term_id:8 doc: 101682 freq: 1),
#   (term_id:8 doc: 10124 freq: 1),
#   (term_id:8 doc: 101882 freq: 3),
#   (term_id:8 doc: 101124 freq: 1),
#   (term_id:8 doc: 101709 freq: 2),
#   (term_id:8 doc: 101707 freq: 3),
#   (term_id:8 doc: 101044 freq: 2),
#   (term_id:8 doc: 101043 freq: 5),
#   (term_id:8 doc: 101663 freq: 5),
#   (term_id:8 doc: 101761 freq: 2),
#   (term_id:8 doc: 101161 freq: 12),
#   (term_id:8 doc: 101409 freq: 2),
#   (term_id:8 doc: 101449 freq: 20),
#   (term_id:8 doc: 101692 freq: 5),
#   (term_id:8 doc: 101118 freq: 2),
#   (term_id:8 doc: 101720 freq: 5),
#   (term_id:8 doc: 101736 freq: 6),
#   (term_id:8 doc: 101755 freq: 1),
#   (term_id:8 doc: 101841 freq: 2),
#   (term_id:8 doc: 10106 freq: 1),
#   (term_id:8 doc: 101654 freq: 7),
#   (term_id:8 doc: 101743 freq: 1),
#   (term_id:8 doc: 101676 freq: 1),
#   (term_id:8 doc: 101150 freq: 1),
#   (term_id:8 doc: 101751 freq: 4),
#   (term_id:8 doc: 101686 freq: 1),
#   (term_id:8 doc: 101703 freq: 3),
#   (term_id:8 doc: 10110 freq: 1),
#   (term_id:8 doc: 101565 freq: 1),
#   (term_id:8 doc: 101670 freq: 3),
#   (term_id:8 doc: 10130 freq: 2),
#   (term_id:8 doc: 101679 freq: 1),
#   (term_id:8 doc: 101691 freq: 4),
#   (term_id:8 doc: 101992 freq: 1),
#   (term_id:8 doc: 101685 freq: 1),
#   (term_id:8 doc: 101652 freq: 5),
#   (term_id:8 doc: 101486 freq: 1),
#   (term_id:8 doc: 101711 freq: 1),
#   (term_id:8 doc: 101708 freq: 1),
#   (term_id:8 doc: 101662 freq: 5),
#   (term_id:8 doc: 101937 freq: 1),
#   (term_id:8 doc: 101694 freq: 5),
#   (term_id:8 doc: 101684 freq: 1),
#   (term_id:8 doc: 101699 freq: 2),
#   (term_id:8 doc: 10149 freq: 3),
#   (term_id:8 doc: 101922 freq: 2),
#   (term_id:8 doc: 101141 freq: 1),
#   (term_id:8 doc: 101661 freq: 5),
#   (term_id:8 doc: 100765 freq: 1),
#   (term_id:8 doc: 100701 freq: 1),
#   (term_id:8 doc: 100626 freq: 4),
#   (term_id:8 doc: 10038 freq: 1),
#   (term_id:8 doc: 10088 freq: 1),
#   (term_id:8 doc: 100892 freq: 1),
#   (term_id:8 doc: 1005 freq: 1),
#   (term_id:8 doc: 100667 freq: 1),
#   (term_id:8 doc: 100661 freq: 1),
#   (term_id:8 doc: 100936 freq: 3),
#   (term_id:8 doc: 100710 freq: 1),
#   (term_id:8 doc: 100635 freq: 1),
#   (term_id:8 doc: 100344 freq: 1),
#   (term_id:8 doc: 100831 freq: 1),
#   (term_id:8 doc: 100157 freq: 2),
#   (term_id:8 doc: 100480 freq: 1),
#   (term_id:8 doc: 100552 freq: 4),
#   (term_id:8 doc: 100658 freq: 1),
#   (term_id:8 doc: 100659 freq: 1),
#   (term_id:8 doc: 100345 freq: 1),
#   (term_id:8 doc: 10023 freq: 1),
#   (term_id:8 doc: 100078 freq: 1),
#   (term_id:8 doc: 10080 freq: 1),
#   (term_id:8 doc: 100042 freq: 1),
#   (term_id:8 doc: 100160 freq: 1),
#   (term_id:8 doc: 1008 freq: 3),
#   (term_id:8 doc: 100662 freq: 1),
#   (term_id:8 doc: 100026 freq: 1),
#   (term_id:8 doc: 100799 freq: 1),
#   (term_id:8 doc: 100768 freq: 1),
#   (term_id:8 doc: 100740 freq: 1),
#   (term_id:8 doc: 1000 freq: 2),
#   (term_id:8 doc: 100205 freq: 1),
#   (term_id:8 doc: 100795 freq: 1),
#   (term_id:8 doc: 100663 freq: 1),
#   (term_id:8 doc: 100105 freq: 1),
#   (term_id:8 doc: 100340 freq: 2),
#   (term_id:8 doc: 100660 freq: 1)],
#  'novembr': [(term_id:9 doc: 101451 freq: 22),
#   (term_id:9 doc: 101537 freq: 3),
#   (term_id:9 doc: 10121 freq: 1),
#   (term_id:9 doc: 101785 freq: 1),
#   (term_id:9 doc: 101960 freq: 1),
#   (term_id:9 doc: 101667 freq: 1),
#   (term_id:9 doc: 101168 freq: 5),
#   (term_id:9 doc: 10144 freq: 1),
#   (term_id:9 doc: 101547 freq: 1),
#   (term_id:9 doc: 10140 freq: 1),
#   (term_id:9 doc: 101433 freq: 1),
#   (term_id:9 doc: 101710 freq: 2),
#   (term_id:9 doc: 101469 freq: 22),
#   (term_id:9 doc: 101480 freq: 12),
#   (term_id:9 doc: 101682 freq: 1),
#   (term_id:9 doc: 101719 freq: 1),
#   (term_id:9 doc: 10105 freq: 1),
#   (term_id:9 doc: 101882 freq: 1),
#   (term_id:9 doc: 101124 freq: 4),
#   (term_id:9 doc: 101477 freq: 2),
#   (term_id:9 doc: 101707 freq: 1),
#   (term_id:9 doc: 101817 freq: 2),
#   (term_id:9 doc: 101656 freq: 2),
#   (term_id:9 doc: 101889 freq: 1),
#   (term_id:9 doc: 101044 freq: 1),
#   (term_id:9 doc: 101043 freq: 4),
#   (term_id:9 doc: 101663 freq: 3),
#   (term_id:9 doc: 10148 freq: 1),
#   (term_id:9 doc: 101820 freq: 1),
#   (term_id:9 doc: 101313 freq: 1),
#   (term_id:9 doc: 101761 freq: 1),
#   (term_id:9 doc: 101248 freq: 1),
#   (term_id:9 doc: 101161 freq: 13),
#   (term_id:9 doc: 101409 freq: 3),
#   (term_id:9 doc: 101449 freq: 21),
#   (term_id:9 doc: 10127 freq: 2),
#   (term_id:9 doc: 101759 freq: 1),
#   (term_id:9 doc: 101720 freq: 1),
#   (term_id:9 doc: 10170 freq: 1),
#   (term_id:9 doc: 101841 freq: 1),
#   (term_id:9 doc: 10106 freq: 1),
#   (term_id:9 doc: 101093 freq: 1),
#   (term_id:9 doc: 10145 freq: 1),
#   (term_id:9 doc: 10126 freq: 1),
#   (term_id:9 doc: 101659 freq: 2),
#   (term_id:9 doc: 101473 freq: 18),
#   (term_id:9 doc: 101703 freq: 7),
#   (term_id:9 doc: 101565 freq: 2),
#   (term_id:9 doc: 101051 freq: 3),
#   (term_id:9 doc: 101981 freq: 1),
#   (term_id:9 doc: 10128 freq: 2),
#   (term_id:9 doc: 10130 freq: 1),
#   (term_id:9 doc: 101679 freq: 3),
#   (term_id:9 doc: 101486 freq: 1),
#   (term_id:9 doc: 101708 freq: 3),
#   (term_id:9 doc: 10196 freq: 2),
#   (term_id:9 doc: 101197 freq: 1),
#   (term_id:9 doc: 101684 freq: 1),
#   (term_id:9 doc: 101665 freq: 1),
#   (term_id:9 doc: 101699 freq: 4),
#   (term_id:9 doc: 10149 freq: 2),
#   (term_id:9 doc: 101059 freq: 1),
#   (term_id:9 doc: 101764 freq: 1),
#   (term_id:9 doc: 101082 freq: 1),
#   (term_id:9 doc: 10058 freq: 1),
#   (term_id:9 doc: 100765 freq: 4),
#   (term_id:9 doc: 100454 freq: 1),
#   (term_id:9 doc: 100021 freq: 1),
#   (term_id:9 doc: 100946 freq: 1),
#   (term_id:9 doc: 100900 freq: 1),
#   (term_id:9 doc: 100120 freq: 1),
#   (term_id:9 doc: 100350 freq: 1),
#   (term_id:9 doc: 100889 freq: 1),
#   (term_id:9 doc: 10005 freq: 1),
#   (term_id:9 doc: 100936 freq: 5),
#   (term_id:9 doc: 100735 freq: 1),
#   (term_id:9 doc: 100448 freq: 1),
#   (term_id:9 doc: 100724 freq: 1),
#   (term_id:9 doc: 100710 freq: 2),
#   (term_id:9 doc: 100344 freq: 4),
#   (term_id:9 doc: 100157 freq: 6),
#   (term_id:9 doc: 100480 freq: 4),
#   (term_id:9 doc: 100552 freq: 4),
#   (term_id:9 doc: 10073 freq: 1),
#   (term_id:9 doc: 100854 freq: 6),
#   (term_id:9 doc: 100540 freq: 1),
#   (term_id:9 doc: 10023 freq: 4),
#   (term_id:9 doc: 100184 freq: 1),
#   (term_id:9 doc: 100426 freq: 1),
#   (term_id:9 doc: 100683 freq: 2),
#   (term_id:9 doc: 1008 freq: 1),
#   (term_id:9 doc: 10015 freq: 1),
#   (term_id:9 doc: 100768 freq: 1),
#   (term_id:9 doc: 10049 freq: 6),
#   (term_id:9 doc: 100795 freq: 2),
#   (term_id:9 doc: 10031 freq: 1),
#   (term_id:9 doc: 100234 freq: 1),
#   (term_id:9 doc: 10008 freq: 2),
#   (term_id:9 doc: 100245 freq: 1)],
#  '1978': [(term_id:10 doc: 101451 freq: 21),
#   (term_id:10 doc: 101750 freq: 1),
#   (term_id:10 doc: 101763 freq: 1),
#   (term_id:10 doc: 101547 freq: 1),
#   (term_id:10 doc: 101740 freq: 1),
#   (term_id:10 doc: 101653 freq: 1),
#   (term_id:10 doc: 101710 freq: 1),
#   (term_id:10 doc: 101719 freq: 1),
#   (term_id:10 doc: 101706 freq: 1),
#   (term_id:10 doc: 101702 freq: 2),
#   (term_id:10 doc: 101675 freq: 2),
#   (term_id:10 doc: 10147 freq: 2),
#   (term_id:10 doc: 101733 freq: 2),
#   (term_id:10 doc: 101687 freq: 2),
#   (term_id:10 doc: 101707 freq: 3),
#   (term_id:10 doc: 101714 freq: 1),
#   (term_id:10 doc: 10198 freq: 2),
#   (term_id:10 doc: 101663 freq: 2),
#   (term_id:10 doc: 101761 freq: 3),
#   (term_id:10 doc: 10138 freq: 4),
#   (term_id:10 doc: 101738 freq: 2),
#   (term_id:10 doc: 101449 freq: 39),
#   (term_id:10 doc: 101692 freq: 1),
#   (term_id:10 doc: 101720 freq: 5),
#   (term_id:10 doc: 101736 freq: 4),
#   (term_id:10 doc: 10170 freq: 1),
#   (term_id:10 doc: 101715 freq: 3),
#   (term_id:10 doc: 101745 freq: 2),
#   (term_id:10 doc: 101717 freq: 3),
#   (term_id:10 doc: 101755 freq: 2),
#   (term_id:10 doc: 101743 freq: 2),
#   (term_id:10 doc: 101722 freq: 1),
#   (term_id:10 doc: 101677 freq: 1),
#   (term_id:10 doc: 101327 freq: 1),
#   (term_id:10 doc: 101751 freq: 2),
#   (term_id:10 doc: 101686 freq: 1),
#   (term_id:10 doc: 101703 freq: 1),
#   (term_id:10 doc: 10150 freq: 2),
#   (term_id:10 doc: 101696 freq: 1),
#   (term_id:10 doc: 101163 freq: 1),
#   (term_id:10 doc: 101046 freq: 1),
#   (term_id:10 doc: 101329 freq: 1),
#   (term_id:10 doc: 101318 freq: 2),
#   (term_id:10 doc: 101652 freq: 10),
#   (term_id:10 doc: 101662 freq: 1),
#   (term_id:10 doc: 101694 freq: 1),
#   (term_id:10 doc: 101705 freq: 2),
#   (term_id:10 doc: 101699 freq: 2),
#   (term_id:10 doc: 101704 freq: 3),
#   (term_id:10 doc: 101922 freq: 3),
#   (term_id:10 doc: 101748 freq: 1),
#   (term_id:10 doc: 101747 freq: 2),
#   (term_id:10 doc: 100562 freq: 5),
#   (term_id:10 doc: 100709 freq: 1),
#   (term_id:10 doc: 100357 freq: 2),
#   (term_id:10 doc: 10018 freq: 3),
#   (term_id:10 doc: 100136 freq: 1),
#   (term_id:10 doc: 100724 freq: 4),
#   (term_id:10 doc: 100902 freq: 1),
#   (term_id:10 doc: 100344 freq: 2),
#   (term_id:10 doc: 100854 freq: 2),
#   (term_id:10 doc: 100741 freq: 1),
#   (term_id:10 doc: 100151 freq: 1),
#   (term_id:10 doc: 100592 freq: 3),
#   (term_id:10 doc: 100704 freq: 1),
#   (term_id:10 doc: 10008 freq: 1),
# ...
#   (term_id:993 doc: 100042 freq: 1),
#   (term_id:993 doc: 10099 freq: 1),
#   (term_id:993 doc: 100785 freq: 1),
#   (term_id:993 doc: 10015 freq: 1),
#   (term_id:993 doc: 100980 freq: 2),
#   (term_id:993 doc: 1006 freq: 1),
#   (term_id:993 doc: 100245 freq: 1)],
#  'fortement': [(term_id:994 doc: 101255 freq: 1),
#   (term_id:994 doc: 10156 freq: 1),
#   (term_id:994 doc: 101923 freq: 1),
#   (term_id:994 doc: 1018 freq: 2),
#   (term_id:994 doc: 101262 freq: 1),
#   (term_id:994 doc: 10139 freq: 1),
#   (term_id:994 doc: 101921 freq: 1),
#   (term_id:994 doc: 10134 freq: 1),
#   (term_id:994 doc: 10107 freq: 1),
#   (term_id:994 doc: 10110 freq: 1),
#   (term_id:994 doc: 10128 freq: 1),
#   (term_id:994 doc: 101329 freq: 1),
#   (term_id:994 doc: 101992 freq: 1),
#   (term_id:994 doc: 101970 freq: 1),
#   (term_id:994 doc: 101652 freq: 1),
#   (term_id:994 doc: 101756 freq: 1),
#   (term_id:994 doc: 10196 freq: 1),
#   (term_id:994 doc: 101830 freq: 1),
#   (term_id:994 doc: 101919 freq: 1),
#   (term_id:994 doc: 100021 freq: 1),
#   (term_id:994 doc: 100221 freq: 1),
#   (term_id:994 doc: 100777 freq: 1),
#   (term_id:994 doc: 100157 freq: 2),
#   (term_id:994 doc: 100821 freq: 1),
#   (term_id:997 doc: 10037 freq: 1),
#   (term_id:997 doc: 10087 freq: 1),
#   (term_id:997 doc: 10084 freq: 1),
#   (term_id:997 doc: 100052 freq: 1)],
#  'defens': [(term_id:998 doc: 101255 freq: 2),
#   (term_id:998 doc: 101660 freq: 1),
#   (term_id:998 doc: 101726 freq: 2),
#   (term_id:998 doc: 101760 freq: 1),
#   (term_id:998 doc: 10109 freq: 2),
#   (term_id:998 doc: 10126 freq: 2),
#   (term_id:998 doc: 10129 freq: 1),
#   (term_id:998 doc: 101652 freq: 1),
#   (term_id:998 doc: 101662 freq: 1),
#   (term_id:998 doc: 101922 freq: 1),
#   (term_id:998 doc: 10020 freq: 1),
#   (term_id:998 doc: 10038 freq: 1),
#   (term_id:998 doc: 100357 freq: 1),
#   (term_id:998 doc: 10024 freq: 1),
#   (term_id:998 doc: 100515 freq: 3),
#   (term_id:998 doc: 100363 freq: 1)],
#  'respect': [(term_id:999 doc: 101255 freq: 1),
#   (term_id:999 doc: 10156 freq: 1),
#   (term_id:999 doc: 10158 freq: 2),
#   (term_id:999 doc: 101695 freq: 1),
#   (term_id:999 doc: 101733 freq: 1),
#   (term_id:999 doc: 101817 freq: 2),
#   (term_id:999 doc: 101161 freq: 1),
#   (term_id:999 doc: 101343 freq: 1),
#   (term_id:999 doc: 101282 freq: 3),
#   (term_id:999 doc: 10119 freq: 1),
#   (term_id:999 doc: 10146 freq: 1),
#   (term_id:999 doc: 10145 freq: 1),
#   (term_id:999 doc: 101505 freq: 1),
#   (term_id:999 doc: 101329 freq: 1),
#   (term_id:999 doc: 101992 freq: 2),
#   (term_id:999 doc: 101708 freq: 2),
#   (term_id:999 doc: 101639 freq: 1),
#   (term_id:999 doc: 10149 freq: 1),
#   (term_id:999 doc: 100995 freq: 1),
#   (term_id:999 doc: 100120 freq: 1),
#   (term_id:999 doc: 100221 freq: 1),
#   (term_id:999 doc: 100107 freq: 1),
#   (term_id:999 doc: 100642 freq: 1),
#   (term_id:999 doc: 100735 freq: 2),
#   (term_id:999 doc: 100448 freq: 3),
#   (term_id:999 doc: 100344 freq: 1),
#   (term_id:999 doc: 100343 freq: 2),
#   (term_id:999 doc: 100854 freq: 1),
#   (term_id:999 doc: 100627 freq: 1),
#   (term_id:999 doc: 100633 freq: 1),
#   (term_id:999 doc: 100720 freq: 1),
#   (term_id:999 doc: 1002 freq: 1)],
#  'mant': [(term_id:1000 doc: 101255 freq: 1),
#   (term_id:1000 doc: 101785 freq: 4),
#   (term_id:1000 doc: 101512 freq: 1),
#   (term_id:1000 doc: 10124 freq: 1),
#   (term_id:1000 doc: 101345 freq: 1),
#   (term_id:1000 doc: 10104 freq: 1),
#   (term_id:1000 doc: 101817 freq: 7),
#   (term_id:1000 doc: 101688 freq: 1),
#   (term_id:1000 doc: 101156 freq: 1),
#   (term_id:1000 doc: 101624 freq: 1),
#   (term_id:1000 doc: 101161 freq: 2),
#   (term_id:1000 doc: 10142 freq: 1),
#   (term_id:1000 doc: 101759 freq: 2),
#   (term_id:1000 doc: 101299 freq: 1),
#   (term_id:1000 doc: 10109 freq: 1),
#   (term_id:1000 doc: 10146 freq: 1),
#   (term_id:1000 doc: 101048 freq: 1),
#   (term_id:1000 doc: 101831 freq: 3),
#   (term_id:1000 doc: 101751 freq: 1),
#   (term_id:1000 doc: 101167 freq: 1),
#   (term_id:1000 doc: 10128 freq: 1),
#   (term_id:1000 doc: 10130 freq: 1),
#   (term_id:1000 doc: 101079 freq: 1),
#   (term_id:1000 doc: 101329 freq: 2),
#   (term_id:1000 doc: 101840 freq: 1),
#   (term_id:1000 doc: 101318 freq: 2),
#   (term_id:1000 doc: 101992 freq: 1),
#   (term_id:1000 doc: 101652 freq: 1),
#   (term_id:1000 doc: 101708 freq: 1),
#   (term_id:1000 doc: 101662 freq: 1),
#   (term_id:1000 doc: 101756 freq: 1),
#   (term_id:1000 doc: 101757 freq: 2),
#   (term_id:1000 doc: 10196 freq: 2),
#   (term_id:1000 doc: 10122 freq: 1),
#   (term_id:1000 doc: 101549 freq: 1),
#   (term_id:1000 doc: 101129 freq: 1),
#   (term_id:1000 doc: 10149 freq: 1),
#   (term_id:1000 doc: 101524 freq: 1),
#   (term_id:1000 doc: 101922 freq: 2),
#   (term_id:1000 doc: 101141 freq: 4),
#   (term_id:1000 doc: 101621 freq: 1),
#   (term_id:1000 doc: 10020 freq: 1),
#   (term_id:1000 doc: 100021 freq: 1),
#   (term_id:1000 doc: 100995 freq: 1),
#   (term_id:1000 doc: 10038 freq: 2),
#   (term_id:1000 doc: 100045 freq: 1),
#   (term_id:1000 doc: 100391 freq: 1),
#   (term_id:1000 doc: 100274 freq: 1),
#   (term_id:1000 doc: 1005 freq: 2),
#   (term_id:1000 doc: 100136 freq: 1),
#   (term_id:1000 doc: 100316 freq: 1),
#   (term_id:1000 doc: 100135 freq: 1),
#   (term_id:1000 doc: 10042 freq: 2),
#   (term_id:1000 doc: 100986 freq: 4),
#   (term_id:1000 doc: 100344 freq: 1),
#   (term_id:1000 doc: 100343 freq: 1),
#   (term_id:1000 doc: 100773 freq: 1),
#   (term_id:1000 doc: 100515 freq: 3),
#   (term_id:1000 doc: 100157 freq: 1),
#   (term_id:1000 doc: 100480 freq: 1),
#   (term_id:1000 doc: 100824 freq: 1),
#   (term_id:1000 doc: 100046 freq: 1),
#   (term_id:1000 doc: 100911 freq: 6),
#   (term_id:1000 doc: 10068 freq: 1),
#   (term_id:1000 doc: 100128 freq: 1),
#   (term_id:1000 doc: 100042 freq: 1),
#   (term_id:1000 doc: 1008 freq: 3),
#   (term_id:1000 doc: 100002 freq: 2),
#   (term_id:1000 doc: 100151 freq: 1),
#   (term_id:1000 doc: 100785 freq: 1),
#   (term_id:1000 doc: 100836 freq: 2),
#   (term_id:1000 doc: 100434 freq: 1),
#   (term_id:1000 doc: 100163 freq: 1),
#   (term_id:1000 doc: 100026 freq: 1),
#   (term_id:1000 doc: 10015 freq: 1),
#   (term_id:1000 doc: 10037 freq: 1),
#   (term_id:1000 doc: 10036 freq: 1),
#   (term_id:1000 doc: 100205 freq: 1),
#   (term_id:1000 doc: 10031 freq: 1),
#   (term_id:1000 doc: 100470 freq: 1),
#   (term_id:1000 doc: 100028 freq: 1),
#   (term_id:1000 doc: 100977 freq: 1),
#   (term_id:1000 doc: 10008 freq: 2),
#   (term_id:1000 doc: 100245 freq: 1)],
#  ...}

# %%
from index.indexer import *
from index.structure import *
from datetime import datetime
import sys, os
import psutil
import json # É necessário JSON para salvar o arquivo em human-readable format

class TermOccurrenceEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance (obj, TermOccurrence):
            return str(obj)
        else:
            return json.JSONEncoder.default(self, obj)

pid = os.getpid() 
obj_index = HashIndex()
html_indexer = HTMLIndexer(obj_index)

start = datetime.now()
memory_start = psutil.Process(pid).memory_info().rss

html_indexer.index_text_dir("wikiSample")

end = datetime.now()
memory_finish = psutil.Process(pid).memory_info().rss

memory_spent = (memory_finish - memory_start) / 1048576 # Em MB na pasta toda\n",
tempo_gasto = (end - start).total_seconds() / 60 # Tempo em minutos

print('Tempo Gasto: '  + str(tempo_gasto))
print('Memória Gasta: ' + str(memory_spent))

# Abrir o arquivo
indexador_global = open('indexador.json', 'w')
json.dump(html_indexer.index.dic_index, indexador_global, cls=TermOccurrenceEncoder)
indexador_global.close()

# Função com problema por causa do encoding
with open('vocabulary.txt', 'w') as vocabulary:
    for word in html_indexer.index.vocabulary:
        try:
            vocabulary.write(word + '\n')
        except:
            print("Erro ao tentar imprimir a palavra:" + str(word))

## Para ler o arquivo de vocabulário
# with open('vocabulary.txt', 'r', encoding='utf-16') as vocabulary:
#    print(vocabulary.read())
# Out:
# Tempo Gasto: 41.43419848333333
# Memória Gasta: 781.92578125

# %%
from index.indexer import *
from index.structure import *
from datetime import datetime
import sys, os
import psutil
import json # É necessário JSON para salvar o arquivo em human-readable format

class TermFilePositionEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance (obj, TermFilePosition):
            return str(obj)
        else:
            return json.JSONEncoder.default(self, obj)

pid = os.getpid()
obj_index = FileIndex()
html_indexer = HTMLIndexer(obj_index)

start = datetime.now()
memory_start = psutil.Process(pid).memory_info().rss

html_indexer.index_text_dir("wikiSample")

end = datetime.now()
memory_finish = psutil.Process(pid).memory_info().rss

memory_spent = (memory_finish - memory_start) / 1048576 # Em MB na pasta toda\n",
tempo_gasto = (end - start).total_seconds() / 60 # Tempo em Minutos

print('Tempo Gasto: '  + str(tempo_gasto))
print('Memória Gasta: ' + str(memory_spent))

# Abrir o arquivo
indexador_global = open('indexador_file_index.json', 'w')
json.dump(html_indexer.index.dic_index, indexador_global, cls=TermFilePositionEncoder)
indexador_global.close()

# Função com problema por causa do unicode
with open('vocabulary_file_index.txt', 'w') as vocabulary:
    for word in html_indexer.index.vocabulary:
        try:
            vocabulary.write(word + '\n')
        except:
            print("Erro ao tentar imprimir a palavra:" + str(word))

## Para ler o arquivo de vocabulário
# with open('vocabulary.txt', 'r') as vocabulary:
#    print(vocabulary.read())
# Out:
# Tempo Gasto: 106.64660226666666
# Memória Gasta: -370.6640625
